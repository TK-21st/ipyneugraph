# %%
from ipyneugraph import NeuGraph
import networkx as nx

# %%
G = nx.read_gexf('lon.gexf')

# %%
nx.

# %%
ng.data
# Out:
# {'nodes': [('nc-LaN-1-R',
#    {'phi': 0.001,
#     'initn': 0.3525,
#     'g_Ca': 4.0,
#     'offset': 0.0,
#     'V_L': -40.0,
#     'V_Ca': 120.0,
#     'Neurotransmitter': 'AchT',
#     'Type': 'VPN',
#     'Side': 'Right',
#     'V_K': -80.0,
#     'name': 'MorrisLecar',
#     'initV': -46.08,
#     'g_L': 3.0,
#     'class': 'MorrisLecar',
#     'V1': -20.0,
#     'V2': 50.0,
#     'V3': -40.0,
#     'V4': 20.0,
#     'g_K': 16.0,
#     'label': 'nc-LaN-1-R'}),
#   ('synapse_Pdf-LaN-1-L_Pdf-LaN-4-L',
#    {'slope': 0.02,
#     'saturation': 0.4,
#     'name': 'PowerGPotGPot',
#     'power': 1.0,
#     'gmax': 0.4,
#     'threshold': -55.0,
#     'class': 'PowerGPotGPot',
#     'reverse': 0.0,
#     'label': 'synapse_Pdf-LaN-1-L_Pdf-LaN-4-L'}),
#   ('Rh5-PR-2-R',
#    {'phi': 0.001,
#     'initn': 0.3525,
#     'g_Ca': 4.0,
#     'offset': 0.0,
#     'V_L': -40.0,
#     'V_Ca': 120.0,
#     'Neurotransmitter': 'AchT',
#     'Type': 'Input',
#     'Side': 'Right',
#     'V_K': -80.0,
#     'name': 'MorrisLecar',
#     'initV': -46.08,
#     'g_L': 3.0,
#     'class': 'MorrisLecar',
#     'V1': -20.0,
#     'V2': 50.0,
#     'V3': -40.0,
#     'V4': 20.0,
#     'g_K': 16.0,
#     'label': 'Rh5-PR-2-R'}),
#   ('nc-LaN-2-R',
#    {'phi': 0.001,
#     'initn': 0.3525,
#     'g_Ca': 4.0,
#     'offset': 0.0,
#     'V_L': -40.0,
#     'V_Ca': 120.0,
#     'Neurotransmitter': 'AchT',
#     'Type': 'VPN',
#     'Side': 'Right',
#     'V_K': -80.0,
#     'name': 'MorrisLecar',
#     'initV': -46.08,
#     'g_L': 3.0,
#     'class': 'MorrisLecar',
#     'V1': -20.0,
#     'V2': 50.0,
#     'V3': -40.0,
#     'V4': 20.0,
#     'g_K': 16.0,
#     'label': 'nc-LaN-2-R'}),
#   ('Rh5-PR-5-R',
#    {'phi': 0.001,
#     'initn': 0.3525,
#     'g_Ca': 4.0,
#     'offset': 0.0,
#     'V_L': -40.0,
#     'V_Ca': 120.0,
#     'Neurotransmitter': 'AchT',
#     'Type': 'Input',
#     'Side': 'Right',
#     'V_K': -80.0,
#     'name': 'MorrisLecar',
#     'initV': -46.08,
#     'g_L': 3.0,
#     'class': 'MorrisLecar',
#     'V1': -20.0,
#     'V2': 50.0,
#     'V3': -40.0,
#     'V4': 20.0,
#     'g_K': 16.0,
#     'label': 'Rh5-PR-5-R'}),
#   ('synapse_Rh6-PR-9-R_glu-lOLP-R',
#    {'slope': 0.02,
#     'saturation': 0.4,
#     'name': 'PowerGPotGPot',
#     'power': 1.0,
#     'gmax': 0.4,
#     'threshold': -55.0,
#     'class': 'PowerGPotGPot',
#     'reverse': 0.0,
#     'label': 'synapse_Rh6-PR-9-R_glu-lOLP-R'}),
#   ('nc-LaN-2-L',
#    {'phi': 0.001,
#     'initn': 0.3525,
#     'g_Ca': 4.0,
#     'offset': 0.0,
#     'V_L': -40.0,
#     'V_Ca': 120.0,
#     'Neurotransmitter': 'AchT',
#     'Type': 'VPN',
#     'Side': 'Left',
#     'V_K': -80.0,
#     'name': 'MorrisLecar',
#     'initV': -46.08,
#     'g_L': 3.0,
#     'class': 'MorrisLecar',
#     'V1': -20.0,
#     'V2': 50.0,
#     'V3': -40.0,
#     'V4': 20.0,
#     'g_K': 16.0,
#     'label': 'nc-LaN-2-L'}),
#   ('synapse_SP2-1-R_5th-LaN-R',
#    {'slope': 0.02,
#     'saturation': 0.4,
#     'name': 'PowerGPotGPot',
#     'power': 1.0,
#     'gmax': 0.4,
#     'threshold': -55.0,
#     'class': 'PowerGPotGPot',
#     'reverse': 0.0,
#     'label': 'synapse_SP2-1-R_5th-LaN-R'}),
#   ('Rh5-PR-2-L',
#    {'phi': 0.001,
#     'initn': 0.3525,
#     'g_Ca': 4.0,
#     'offset': 0.0,
#     'V_L': -40.0,
#     'V_Ca': 120.0,
#     'Neurotransmitter': 'AchT',
#     'Type': 'Input',
#     'Side': 'Left',
#     'V_K': -80.0,
#     'name': 'MorrisLecar',
#     'initV': -46.08,
#     'g_L': 3.0,
#     'class': 'MorrisLecar',
#     'V1': -20.0,
#     'V2': 50.0,
#     'V3': -40.0,
#     'V4': 20.0,
#     'g_K': 16.0,
#     'label': 'Rh5-PR-2-L'}),
#   ('nc-LaN-1-L',
#    {'phi': 0.001,
#     'initn': 0.3525,
#     'g_Ca': 4.0,
#     'offset': 0.0,
#     'V_L': -40.0,
#     'V_Ca': 120.0,
#     'Neurotransmitter': 'AchT',
#     'Type': 'VPN',
#     'Side': 'Left',
#     'V_K': -80.0,
#     'name': 'MorrisLecar',
#     'initV': -46.08,
#     'g_L': 3.0,
#     'class': 'MorrisLecar',
#     'V1': -20.0,
#     'V2': 50.0,
#     'V3': -40.0,
#     'V4': 20.0,
#     'g_K': 16.0,
#     'label': 'nc-LaN-1-L'}),
#   ('synapse_Phasic-VPN-L_PVL09-L',
#    {'slope': 0.02,
#     'saturation': 0.4,
#     'name': 'PowerGPotGPot',
#     'power': 1.0,
#     'gmax': 0.4,
#     'threshold': -55.0,
#     'class': 'PowerGPotGPot',
#     'reverse': -80.0,
#     'label': 'synapse_Phasic-VPN-L_PVL09-L'}),
#   ('Rh5-PR-1-R',
#    {'phi': 0.001,
#     'initn': 0.3525,
#     'g_Ca': 4.0,
#     'offset': 0.0,
#     'V_L': -40.0,
#     'V_Ca': 120.0,
#     'Neurotransmitter': 'AchT',
#     'Type': 'Input',
#     'Side': 'Right',
#     'V_K': -80.0,
#     'name': 'MorrisLecar',
#     'initV': -46.08,
#     'g_L': 3.0,
#     'class': 'MorrisLecar',
#     'V1': -20.0,
#     'V2': 50.0,
#     'V3': -40.0,
#     'V4': 20.0,
#     'g_K': 16.0,
#     'label': 'Rh5-PR-1-R'}),
#   ('Rh5-PR-1-L',
#    {'phi': 0.001,
#     'initn': 0.3525,
#     'g_Ca': 4.0,
#     'offset': 0.0,
#     'V_L': -40.0,
#     'V_Ca': 120.0,
#     'Neurotransmitter': 'AchT',
#     'Type': 'Input',
#     'Side': 'Left',
#     'V_K': -80.0,
#     'name': 'MorrisLecar',
#     'initV': -46.08,
#     'g_L': 3.0,
#     'class': 'MorrisLecar',
#     'V1': -20.0,
#     'V2': 50.0,
#     'V3': -40.0,
#     'V4': 20.0,
#     'g_K': 16.0,
#     'label': 'Rh5-PR-1-L'}),
#   ('synapse_Rh5-PR-5-R_nc-LaN-1-R',
#    {'slope': 0.02,
#     'saturation': 0.4,
#     'name': 'PowerGPotGPot',
#     'power': 1.0,
#     'gmax': 0.4,
#     'threshold': -55.0,
#     'class': 'PowerGPotGPot',
#     'reverse': 0.0,
#     'label': 'synapse_Rh5-PR-5-R_nc-LaN-1-R'}),
#   ('synapse_nc-LaN-2-R_SP2-1-R',
#    {'slope': 0.02,
#     'saturation': 0.4,
#     'name': 'PowerGPotGPot',
#     'power': 1.0,
#     'gmax': 0.4,
#     'threshold': -55.0,
#     'class': 'PowerGPotGPot',
#     'reverse': 0.0,
#     'label': 'synapse_nc-LaN-2-R_SP2-1-R'}),
#   ('synapse_cha-lOLP-L_5th-LaN-L',
#    {'slope': 0.02,
#     'saturation': 0.4,
#     'name': 'PowerGPotGPot',
#     'power': 1.0,
#     'gmax': 0.4,
#     'threshold': -55.0,
#     'class': 'PowerGPotGPot',
#     'reverse': 0.0,
#     'label': 'synapse_cha-lOLP-L_5th-LaN-L'}),
#   ('synapse_Rh5-PR-1-R_extra-glu-lOLP-R',
#    {'slope': 0.02,
#     'saturation': 0.4,
#     'name': 'PowerGPotGPot',
#     'power': 1.0,
#     'gmax': 0.4,
#     'threshold': -55.0,
#     'class': 'PowerGPotGPot',
#     'reverse': 0.0,
#     'label': 'synapse_Rh5-PR-1-R_extra-glu-lOLP-R'}),
#   ('synapse_Rh6-PR-6-R_glu-lOLP-R',
#    {'slope': 0.02,
#     'saturation': 0.4,
#     'name': 'PowerGPotGPot',
#     'power': 1.0,
#     'gmax': 0.4,
#     'threshold': -55.0,
#     'class': 'PowerGPotGPot',
#     'reverse': 0.0,
#     'label': 'synapse_Rh6-PR-6-R_glu-lOLP-R'}),
#   ('synapse_Rh6-PR-4-L_PVL09-L',
#    {'slope': 0.02,
#     'saturation': 0.4,
#     'name': 'PowerGPotGPot',
#     'power': 1.0,
#     'gmax': 0.4,
#     'threshold': -55.0,
#     'class': 'PowerGPotGPot',
#     'reverse': 0.0,
#     'label': 'synapse_Rh6-PR-4-L_PVL09-L'}),
#   ('synapse_glu-lOLP-L_nc-LaN-2-L',
#    {'slope': 0.02,
#     'saturation': 0.4,
#     'name': 'PowerGPotGPot',
#     'power': 1.0,
#     'gmax': 0.4,
#     'threshold': -55.0,
#     'class': 'PowerGPotGPot',
#     'reverse': -80.0,
#     'label': 'synapse_glu-lOLP-L_nc-LaN-2-L'}),
#   ('synapse_glu-lOLP-R_extra-glu-lOLP-R',
#    {'slope': 0.02,
#     'saturation': 0.4,
#     'name': 'PowerGPotGPot',
#     'power': 1.0,
#     'gmax': 0.4,
#     'threshold': -55.0,
#     'class': 'PowerGPotGPot',
#     'reverse': -80.0,
#     'label': 'synapse_glu-lOLP-R_extra-glu-lOLP-R'}),
#   ('synapse_Rh6-PR-6-L_cha-lOLP-L',
#    {'slope': 0.02,
#     'saturation': 0.4,
#     'name': 'PowerGPotGPot',
#     'power': 1.0,
#     'gmax': 0.4,
#     'threshold': -55.0,
#     'class': 'PowerGPotGPot',
#     'reverse': 0.0,
#     'label': 'synapse_Rh6-PR-6-L_cha-lOLP-L'}),
#   ('synapse_Pdf-LaN-1-L_Pdf-LaN-3-L',
#    {'slope': 0.02,
#     'saturation': 0.4,
#     'name': 'PowerGPotGPot',
#     'power': 1.0,
#     'gmax': 0.4,
#     'threshold': -55.0,
#     'class': 'PowerGPotGPot',
#     'reverse': 0.0,
#     'label': 'synapse_Pdf-LaN-1-L_Pdf-LaN-3-L'}),
#   ('synapse_glu-lOLP-R_nc-LaN-1-R',
#    {'slope': 0.02,
#     'saturation': 0.4,
#     'name': 'PowerGPotGPot',
#     'power': 1.0,
#     'gmax': 0.4,
#     'threshold': -55.0,
#     'class': 'PowerGPotGPot',
#     'reverse': -80.0,
#     'label': 'synapse_glu-lOLP-R_nc-LaN-1-R'}),
#   ('synapse_Rh6-PR-5-R_Pdf-LaN-4-R',
#    {'slope': 0.02,
#     'saturation': 0.4,
#     'name': 'PowerGPotGPot',
#     'power': 1.0,
#     'gmax': 0.4,
#     'threshold': -55.0,
#     'class': 'PowerGPotGPot',
#     'reverse': 0.0,
#     'label': 'synapse_Rh6-PR-5-R_Pdf-LaN-4-R'}),
#   ('synapse_Rh6-PR-1-R_glu-lOLP-R',
#    {'slope': 0.02,
#     'saturation': 0.4,
#     'name': 'PowerGPotGPot',
#     'power': 1.0,
#     'gmax': 0.4,
#     'threshold': -55.0,
#     'class': 'PowerGPotGPot',
#     'reverse': 0.0,
#     'label': 'synapse_Rh6-PR-1-R_glu-lOLP-R'}),
#   ('synapse_glu-lOLP-R_nc-LaN-2-R',
#    {'slope': 0.02,
#     'saturation': 0.4,
#     'name': 'PowerGPotGPot',
#     'power': 1.0,
#     'gmax': 0.4,
#     'threshold': -55.0,
#     'class': 'PowerGPotGPot',
#     'reverse': -80.0,
#     'label': 'synapse_glu-lOLP-R_nc-LaN-2-R'}),
#   ('Pdf-LaN-3-R',
#    {'phi': 0.001,
#     'initn': 0.3525,
#     'g_Ca': 4.0,
#     'offset': 0.0,
#     'V_L': -40.0,
#     'V_Ca': 120.0,
#     'Neurotransmitter': 'nan',
#     'Type': 'VPN',
#     'Side': 'Right',
#     'V_K': -80.0,
#     'name': 'MorrisLecar',
#     'initV': -46.08,
#     'g_L': 3.0,
#     'class': 'MorrisLecar',
#     'V1': -20.0,
#     'V2': 50.0,
#     'V3': -40.0,
#     'V4': 20.0,
#     'g_K': 16.0,
#     'label': 'Pdf-LaN-3-R'}),
#   ('synapse_Rh5-PR-2-L_Pdf-LaN-4-L',
#    {'slope': 0.02,
#     'saturation': 0.4,
#     'name': 'PowerGPotGPot',
#     'power': 1.0,
#     'gmax': 0.4,
#     'threshold': -55.0,
#     'class': 'PowerGPotGPot',
#     'reverse': 0.0,
#     'label': 'synapse_Rh5-PR-2-L_Pdf-LaN-4-L'}),
#   ('synapse_Rh6-PR-8-L_Pdf-LaN-4-L',
#    {'slope': 0.02,
#     'saturation': 0.4,
#     'name': 'PowerGPotGPot',
#     'power': 1.0,
#     'gmax': 0.4,
#     'threshold': -55.0,
#     'class': 'PowerGPotGPot',
#     'reverse': 0.0,
#     'label': 'synapse_Rh6-PR-8-L_Pdf-LaN-4-L'}),
#   ('synapse_Rh5-PR-2-L_nc-LaN-1-L',
#    {'slope': 0.02,
#     'saturation': 0.4,
#     'name': 'PowerGPotGPot',
#     'power': 1.0,
#     'gmax': 0.4,
#     'threshold': -55.0,
#     'class': 'PowerGPotGPot',
#     'reverse': 0.0,
#     'label': 'synapse_Rh5-PR-2-L_nc-LaN-1-L'}),
#   ('Pdf-LaN-3-L',
#    {'phi': 0.001,
#     'initn': 0.3525,
#     'g_Ca': 4.0,
#     'offset': 0.0,
#     'V_L': -40.0,
#     'V_Ca': 120.0,
#     'Neurotransmitter': 'nan',
#     'Type': 'VPN',
#     'Side': 'Left',
#     'V_K': -80.0,
#     'name': 'MorrisLecar',
#     'initV': -46.08,
#     'g_L': 3.0,
#     'class': 'MorrisLecar',
#     'V1': -20.0,
#     'V2': 50.0,
#     'V3': -40.0,
#     'V4': 20.0,
#     'g_K': 16.0,
#     'label': 'Pdf-LaN-3-L'}),
#   ('synapse_Rh5-PR-2-L_nc-LaN-2-L',
#    {'slope': 0.02,
#     'saturation': 0.4,
#     'name': 'PowerGPotGPot',
#     'power': 1.0,
#     'gmax': 0.4,
#     'threshold': -55.0,
#     'class': 'PowerGPotGPot',
#     'reverse': 0.0,
#     'label': 'synapse_Rh5-PR-2-L_nc-LaN-2-L'}),
#   ('synapse_nc-LaN-2-L_SP2-1-L',
#    {'slope': 0.02,
#     'saturation': 0.4,
#     'name': 'PowerGPotGPot',
#     'power': 1.0,
#     'gmax': 0.4,
#     'threshold': -55.0,
#     'class': 'PowerGPotGPot',
#     'reverse': 0.0,
#     'label': 'synapse_nc-LaN-2-L_SP2-1-L'}),
#   ('synapse_Pdf-LaN-4-R_SP2-1-R',
#    {'slope': 0.02,
#     'saturation': 0.4,
#     'name': 'PowerGPotGPot',
#     'power': 1.0,
#     'gmax': 0.4,
#     'threshold': -55.0,
#     'class': 'PowerGPotGPot',
#     'reverse': 0.0,
#     'label': 'synapse_Pdf-LaN-4-R_SP2-1-R'}),
#   ('synapse_Phasic-VPN-L_5th-LaN-L',
#    {'slope': 0.02,
#     'saturation': 0.4,
#     'name': 'PowerGPotGPot',
#     'power': 1.0,
#     'gmax': 0.4,
#     'threshold': -55.0,
#     'class': 'PowerGPotGPot',
#     'reverse': -80.0,
#     'label': 'synapse_Phasic-VPN-L_5th-LaN-L'}),
#   ('synapse_Rh5-PR-2-L_Pdf-LaN-3-L',
#    {'slope': 0.02,
#     'saturation': 0.4,
#     'name': 'PowerGPotGPot',
#     'power': 1.0,
#     'gmax': 0.4,
#     'threshold': -55.0,
#     'class': 'PowerGPotGPot',
#     'reverse': 0.0,
#     'label': 'synapse_Rh5-PR-2-L_Pdf-LaN-3-L'}),
#   ('synapse_sVUM2mx-R_sVUM2md-R',
#    {'slope': 0.02,
#     'saturation': 0.4,
#     'name': 'PowerGPotGPot',
#     'power': 1.0,
#     'gmax': 0.4,
#     'threshold': -55.0,
#     'class': 'PowerGPotGPot',
#     'reverse': 0.0,
#     'label': 'synapse_sVUM2mx-R_sVUM2md-R'}),
#   ('synapse_nc-LaN-2-L_5th-LaN-L',
#    {'slope': 0.02,
#     'saturation': 0.4,
#     'name': 'PowerGPotGPot',
#     'power': 1.0,
#     'gmax': 0.4,
#     'threshold': -55.0,
#     'class': 'PowerGPotGPot',
#     'reverse': 0.0,
#     'label': 'synapse_nc-LaN-2-L_5th-LaN-L'}),
#   ('synapse_Rh5-PR-1-R_5th-LaN-R',
#    {'slope': 0.02,
#     'saturation': 0.4,
#     'name': 'PowerGPotGPot',
#     'power': 1.0,
#     'gmax': 0.4,
#     'threshold': -55.0,
#     'class': 'PowerGPotGPot',
#     'reverse': 0.0,
#     'label': 'synapse_Rh5-PR-1-R_5th-LaN-R'}),
#   ('synapse_Rh6-PR-4-L_cha-lOLP-L',
#    {'slope': 0.02,
#     'saturation': 0.4,
#     'name': 'PowerGPotGPot',
#     'power': 1.0,
#     'gmax': 0.4,
#     'threshold': -55.0,
#     'class': 'PowerGPotGPot',
#     'reverse': 0.0,
#     'label': 'synapse_Rh6-PR-4-L_cha-lOLP-L'}),
#   ('synapse_Rh5-PR-5-R_nc-LaN-2-R',
#    {'slope': 0.02,
#     'saturation': 0.4,
#     'name': 'PowerGPotGPot',
#     'power': 1.0,
#     'gmax': 0.4,
#     'threshold': -55.0,
#     'class': 'PowerGPotGPot',
#     'reverse': 0.0,
#     'label': 'synapse_Rh5-PR-5-R_nc-LaN-2-R'}),
#   ('synapse_Rh6-PR-10-R_Pdf-LaN-2-R',
#    {'slope': 0.02,
#     'saturation': 0.4,
#     'name': 'PowerGPotGPot',
#     'power': 1.0,
#     'gmax': 0.4,
#     'threshold': -55.0,
#     'class': 'PowerGPotGPot',
#     'reverse': 0.0,
#     'label': 'synapse_Rh6-PR-10-R_Pdf-LaN-2-R'}),
#   ('synapse_nc-LaN-1-R_PVL09-R',
#    {'slope': 0.02,
#     'saturation': 0.4,
#     'name': 'PowerGPotGPot',
#     'power': 1.0,
#     'gmax': 0.4,
#     'threshold': -55.0,
#     'class': 'PowerGPotGPot',
#     'reverse': 0.0,
#     'label': 'synapse_nc-LaN-1-R_PVL09-R'}),
#   ('synapse_Rh6-PR-6-R_cha-lOLP-R',
#    {'slope': 0.02,
#     'saturation': 0.4,
#     'name': 'PowerGPotGPot',
#     'power': 1.0,
#     'gmax': 0.4,
#     'threshold': -55.0,
#     'class': 'PowerGPotGPot',
#     'reverse': 0.0,
#     'label': 'synapse_Rh6-PR-6-R_cha-lOLP-R'}),
#   ('synapse_Rh6-PR-10-R_nc-LaN-2-R',
#    {'slope': 0.02,
#     'saturation': 0.4,
#     'name': 'PowerGPotGPot',
#     'power': 1.0,
#     'gmax': 0.4,
#     'threshold': -55.0,
#     'class': 'PowerGPotGPot',
#     'reverse': 0.0,
#     'label': 'synapse_Rh6-PR-10-R_nc-LaN-2-R'}),
#   ('synapse_Rh6-PR-8-L_Pdf-LaN-3-L',
#    {'slope': 0.02,
#     'saturation': 0.4,
#     'name': 'PowerGPotGPot',
#     'power': 1.0,
#     'gmax': 0.4,
#     'threshold': -55.0,
#     'class': 'PowerGPotGPot',
#     'reverse': 0.0,
#     'label': 'synapse_Rh6-PR-8-L_Pdf-LaN-3-L'}),
#   ('synapse_Rh6-PR-5-L_cha-lOLP-L',
#    {'slope': 0.02,
#     'saturation': 0.4,
#     'name': 'PowerGPotGPot',
#     'power': 1.0,
#     'gmax': 0.4,
#     'threshold': -55.0,
#     'class': 'PowerGPotGPot',
#     'reverse': 0.0,
#     'label': 'synapse_Rh6-PR-5-L_cha-lOLP-L'}),
#   ('synapse_Phasic-VPN-L_pOLP-L',
#    {'slope': 0.02,
#     'saturation': 0.4,
#     'name': 'PowerGPotGPot',
#     'power': 1.0,
#     'gmax': 0.4,
#     'threshold': -55.0,
#     'class': 'PowerGPotGPot',
#     'reverse': -80.0,
#     'label': 'synapse_Phasic-VPN-L_pOLP-L'}),
#   ('synapse_extra-glu-lOLP-R_extra-glu-lOLP-R',
#    {'slope': 0.02,
#     'saturation': 0.4,
#     'name': 'PowerGPotGPot',
#     'power': 1.0,
#     'gmax': 0.4,
#     'threshold': -55.0,
#     'class': 'PowerGPotGPot',
#     'reverse': -80.0,
#     'label': 'synapse_extra-glu-lOLP-R_extra-glu-lOLP-R'}),
#   ('synapse_glu-lOLP-R_glu-lOLP-R',
#    {'slope': 0.02,
#     'saturation': 0.4,
#     'name': 'PowerGPotGPot',
#     'power': 1.0,
#     'gmax': 0.4,
#     'threshold': -55.0,
#     'class': 'PowerGPotGPot',
#     'reverse': -80.0,
#     'label': 'synapse_glu-lOLP-R_glu-lOLP-R'}),
#   ('synapse_Phasic-VPN-R_extra-glu-lOLP-R',
#    {'slope': 0.02,
#     'saturation': 0.4,
#     'name': 'PowerGPotGPot',
#     'power': 1.0,
#     'gmax': 0.4,
#     'threshold': -55.0,
#     'class': 'PowerGPotGPot',
#     'reverse': -80.0,
#     'label': 'synapse_Phasic-VPN-R_extra-glu-lOLP-R'}),
#   ('synapse_Rh5-PR-2-R_PVL09-R',
#    {'slope': 0.02,
#     'saturation': 0.4,
#     'name': 'PowerGPotGPot',
#     'power': 1.0,
#     'gmax': 0.4,
#     'threshold': -55.0,
#     'class': 'PowerGPotGPot',
#     'reverse': 0.0,
#     'label': 'synapse_Rh5-PR-2-R_PVL09-R'}),
#   ('synapse_sVUM2md-L_glu-lOLP-L',
#    {'slope': 0.02,
#     'saturation': 0.4,
#     'name': 'PowerGPotGPot',
#     'power': 1.0,
#     'gmax': 0.4,
#     'threshold': -55.0,
#     'class': 'PowerGPotGPot',
#     'reverse': 0.0,
#     'label': 'synapse_sVUM2md-L_glu-lOLP-L'}),
#   ('synapse_cha-lOLP-R_cha-lOLP-R',
#    {'slope': 0.02,
#     'saturation': 0.4,
#     'name': 'PowerGPotGPot',
#     'power': 1.0,
#     'gmax': 0.4,
#     'threshold': -55.0,
#     'class': 'PowerGPotGPot',
#     'reverse': 0.0,
#     'label': 'synapse_cha-lOLP-R_cha-lOLP-R'}),
#   ('Rh5-PR-4-R',
#    {'phi': 0.001,
#     'initn': 0.3525,
#     'g_Ca': 4.0,
#     'offset': 0.0,
#     'V_L': -40.0,
#     'V_Ca': 120.0,
#     'Neurotransmitter': 'AchT',
#     'Type': 'Input',
#     'Side': 'Right',
#     'V_K': -80.0,
#     'name': 'MorrisLecar',
#     'initV': -46.08,
#     'g_L': 3.0,
#     'class': 'MorrisLecar',
#     'V1': -20.0,
#     'V2': 50.0,
#     'V3': -40.0,
#     'V4': 20.0,
#     'g_K': 16.0,
#     'label': 'Rh5-PR-4-R'}),
#   ('Rh5-PR-4-L',
#    {'phi': 0.001,
#     'initn': 0.3525,
#     'g_Ca': 4.0,
#     'offset': 0.0,
#     'V_L': -40.0,
#     'V_Ca': 120.0,
#     'Neurotransmitter': 'AchT',
#     'Type': 'Input',
#     'Side': 'Left',
#     'V_K': -80.0,
#     'name': 'MorrisLecar',
#     'initV': -46.08,
#     'g_L': 3.0,
#     'class': 'MorrisLecar',
#     'V1': -20.0,
#     'V2': 50.0,
#     'V3': -40.0,
#     'V4': 20.0,
#     'g_K': 16.0,
#     'label': 'Rh5-PR-4-L'}),
#   ('synapse_Rh6-PR-4-R_extra-glu-lOLP-R',
#    {'slope': 0.02,
#     'saturation': 0.4,
#     'name': 'PowerGPotGPot',
#     'power': 1.0,
#     'gmax': 0.4,
#     'threshold': -55.0,
#     'class': 'PowerGPotGPot',
#     'reverse': 0.0,
#     'label': 'synapse_Rh6-PR-4-R_extra-glu-lOLP-R'}),
#   ('synapse_sVUM2mx-R_cha-lOLP-R',
#    {'slope': 0.02,
#     'saturation': 0.4,
#     'name': 'PowerGPotGPot',
#     'power': 1.0,
#     'gmax': 0.4,
#     'threshold': -55.0,
#     'class': 'PowerGPotGPot',
#     'reverse': 0.0,
#     'label': 'synapse_sVUM2mx-R_cha-lOLP-R'}),
#   ('Rh6-PR-8-L',
#    {'phi': 0.001,
#     'initn': 0.3525,
#     'g_Ca': 4.0,
#     'offset': 0.0,
#     'V_L': -40.0,
#     'V_Ca': 120.0,
#     'Neurotransmitter': 'AchT',
#     'Type': 'Input',
#     'Side': 'Left',
#     'V_K': -80.0,
#     'name': 'MorrisLecar',
#     'initV': -46.08,
#     'g_L': 3.0,
#     'class': 'MorrisLecar',
#     'V1': -20.0,
#     'V2': 50.0,
#     'V3': -40.0,
#     'V4': 20.0,
#     'g_K': 16.0,
#     'label': 'Rh6-PR-8-L'}),
#   ('synapse_Rh5-PR-3-L_5th-LaN-L',
#    {'slope': 0.02,
#     'saturation': 0.4,
#     'name': 'PowerGPotGPot',
#     'power': 1.0,
#     'gmax': 0.4,
#     'threshold': -55.0,
#     'class': 'PowerGPotGPot',
#     'reverse': 0.0,
#     'label': 'synapse_Rh5-PR-3-L_5th-LaN-L'}),
#   ('Rh5-PR-3-R',
#    {'phi': 0.001,
#     'initn': 0.3525,
#     'g_Ca': 4.0,
#     'offset': 0.0,
#     'V_L': -40.0,
#     'V_Ca': 120.0,
#     'Neurotransmitter': 'AchT',
#     'Type': 'Input',
#     'Side': 'Right',
#     'V_K': -80.0,
#     'name': 'MorrisLecar',
#     'initV': -46.08,
#     'g_L': 3.0,
#     'class': 'MorrisLecar',
#     'V1': -20.0,
#     'V2': 50.0,
#     'V3': -40.0,
#     'V4': 20.0,
#     'g_K': 16.0,
#     'label': 'Rh5-PR-3-R'}),
#   ('synapse_Rh5-PR-5-R_extra-glu-lOLP-R',
#    {'slope': 0.02,
#     'saturation': 0.4,
#     'name': 'PowerGPotGPot',
#     'power': 1.0,
#     'gmax': 0.4,
#     'threshold': -55.0,
#     'class': 'PowerGPotGPot',
#     'reverse': 0.0,
#     'label': 'synapse_Rh5-PR-5-R_extra-glu-lOLP-R'}),
#   ('synapse_Rh6-PR-3-R_cha-lOLP-R',
#    {'slope': 0.02,
#     'saturation': 0.4,
#     'name': 'PowerGPotGPot',
#     'power': 1.0,
#     'gmax': 0.4,
#     'threshold': -55.0,
#     'class': 'PowerGPotGPot',
#     'reverse': 0.0,
#     'label': 'synapse_Rh6-PR-3-R_cha-lOLP-R'}),
#   ('Rh5-PR-3-L',
#    {'phi': 0.001,
#     'initn': 0.3525,
#     'g_Ca': 4.0,
#     'offset': 0.0,
#     'V_L': -40.0,
#     'V_Ca': 120.0,
#     'Neurotransmitter': 'AchT',
#     'Type': 'Input',
#     'Side': 'Left',
#     'V_K': -80.0,
#     'name': 'MorrisLecar',
#     'initV': -46.08,
#     'g_L': 3.0,
#     'class': 'MorrisLecar',
#     'V1': -20.0,
#     'V2': 50.0,
#     'V3': -40.0,
#     'V4': 20.0,
#     'g_K': 16.0,
#     'label': 'Rh5-PR-3-L'}),
#   ('synapse_cha-lOLP-L_Phasic-VPN-L',
#    {'slope': 0.02,
#     'saturation': 0.4,
#     'name': 'PowerGPotGPot',
#     'power': 1.0,
#     'gmax': 0.4,
#     'threshold': -55.0,
#     'class': 'PowerGPotGPot',
#     'reverse': 0.0,
#     'label': 'synapse_cha-lOLP-L_Phasic-VPN-L'}),
#   ('Rh6-PR-8-R',
#    {'phi': 0.001,
#     'initn': 0.3525,
#     'g_Ca': 4.0,
#     'offset': 0.0,
#     'V_L': -40.0,
#     'V_Ca': 120.0,
#     'Neurotransmitter': 'AchT',
#     'Type': 'Input',
#     'Side': 'Right',
#     'V_K': -80.0,
#     'name': 'MorrisLecar',
#     'initV': -46.08,
#     'g_L': 3.0,
#     'class': 'MorrisLecar',
#     'V1': -20.0,
#     'V2': 50.0,
#     'V3': -40.0,
#     'V4': 20.0,
#     'g_K': 16.0,
#     'label': 'Rh6-PR-8-R'}),
#   ('synapse_Rh5-PR-6-R_pOLP-R',
#    {'slope': 0.02,
#     'saturation': 0.4,
#     'name': 'PowerGPotGPot',
#     'power': 1.0,
#     'gmax': 0.4,
#     'threshold': -55.0,
#     'class': 'PowerGPotGPot',
#     'reverse': 0.0,
#     'label': 'synapse_Rh5-PR-6-R_pOLP-R'}),
#   ('synapse_Rh6-PR-6-L_glu-lOLP-L',
#    {'slope': 0.02,
#     'saturation': 0.4,
#     'name': 'PowerGPotGPot',
#     'power': 1.0,
#     'gmax': 0.4,
#     'threshold': -55.0,
#     'class': 'PowerGPotGPot',
#     'reverse': 0.0,
#     'label': 'synapse_Rh6-PR-6-L_glu-lOLP-L'}),
#   ('synapse_SP2-1-L_nc-LaN-1-L',
#    {'slope': 0.02,
#     'saturation': 0.4,
#     'name': 'PowerGPotGPot',
#     'power': 1.0,
#     'gmax': 0.4,
#     'threshold': -55.0,
#     'class': 'PowerGPotGPot',
#     'reverse': 0.0,
#     'label': 'synapse_SP2-1-L_nc-LaN-1-L'}),
#   ('synapse_5th-LaN-L_Pdf-LaN-4-L',
#    {'slope': 0.02,
#     'saturation': 0.4,
#     'name': 'PowerGPotGPot',
#     'power': 1.0,
#     'gmax': 0.4,
#     'threshold': -55.0,
#     'class': 'PowerGPotGPot',
#     'reverse': 0.0,
#     'label': 'synapse_5th-LaN-L_Pdf-LaN-4-L'}),
#   ('synapse_nc-LaN-1-L_Pdf-LaN-1-L',
#    {'slope': 0.02,
#     'saturation': 0.4,
#     'name': 'PowerGPotGPot',
#     'power': 1.0,
#     'gmax': 0.4,
#     'threshold': -55.0,
#     'class': 'PowerGPotGPot',
#     'reverse': 0.0,
#     'label': 'synapse_nc-LaN-1-L_Pdf-LaN-1-L'}),
#   ('synapse_nc-LaN-1-R_5th-LaN-R',
#    {'slope': 0.02,
#     'saturation': 0.4,
#     'name': 'PowerGPotGPot',
#     'power': 1.0,
#     'gmax': 0.4,
#     'threshold': -55.0,
#     'class': 'PowerGPotGPot',
#     'reverse': 0.0,
#     'label': 'synapse_nc-LaN-1-R_5th-LaN-R'}),
#   ('synapse_SP2-1-L_nc-LaN-2-L',
#    {'slope': 0.02,
#     'saturation': 0.4,
#     'name': 'PowerGPotGPot',
#     'power': 1.0,
#     'gmax': 0.4,
#     'threshold': -55.0,
#     'class': 'PowerGPotGPot',
#     'reverse': 0.0,
#     'label': 'synapse_SP2-1-L_nc-LaN-2-L'}),
#   ('synapse_PVL09-L_pOLP-L',
#    {'slope': 0.02,
#     'saturation': 0.4,
#     'name': 'PowerGPotGPot',
#     'power': 1.0,
#     'gmax': 0.4,
#     'threshold': -55.0,
#     'class': 'PowerGPotGPot',
#     'reverse': 0.0,
#     'label': 'synapse_PVL09-L_pOLP-L'}),
#   ('synapse_Rh5-PR-5-R_cha-lOLP-R',
#    {'slope': 0.02,
#     'saturation': 0.4,
#     'name': 'PowerGPotGPot',
#     'power': 1.0,
#     'gmax': 0.4,
#     'threshold': -55.0,
#     'class': 'PowerGPotGPot',
#     'reverse': 0.0,
#     'label': 'synapse_Rh5-PR-5-R_cha-lOLP-R'}),
#   ('synapse_Phasic-VPN-L_glu-lOLP-L',
#    {'slope': 0.02,
#     'saturation': 0.4,
#     'name': 'PowerGPotGPot',
#     'power': 1.0,
#     'gmax': 0.4,
#     'threshold': -55.0,
#     'class': 'PowerGPotGPot',
#     'reverse': -80.0,
#     'label': 'synapse_Phasic-VPN-L_glu-lOLP-L'}),
#   ('Rh6-PR-3-R',
#    {'phi': 0.001,
#     'initn': 0.3525,
#     'g_Ca': 4.0,
#     'offset': 0.0,
#     'V_L': -40.0,
#     'V_Ca': 120.0,
#     'Neurotransmitter': 'AchT',
#     'Type': 'Input',
#     'Side': 'Right',
#     'V_K': -80.0,
#     'name': 'MorrisLecar',
#     'initV': -46.08,
#     'g_L': 3.0,
#     'class': 'MorrisLecar',
#     'V1': -20.0,
#     'V2': 50.0,
#     'V3': -40.0,
#     'V4': 20.0,
#     'g_K': 16.0,
#     'label': 'Rh6-PR-3-R'}),
#   ('synapse_Rh6-PR-4-R_glu-lOLP-R',
#    {'slope': 0.02,
#     'saturation': 0.4,
#     'name': 'PowerGPotGPot',
#     'power': 1.0,
#     'gmax': 0.4,
#     'threshold': -55.0,
#     'class': 'PowerGPotGPot',
#     'reverse': 0.0,
#     'label': 'synapse_Rh6-PR-4-R_glu-lOLP-R'}),
#   ('synapse_Pdf-LaN-1-L_Pdf-LaN-2-L',
#    {'slope': 0.02,
#     'saturation': 0.4,
#     'name': 'PowerGPotGPot',
#     'power': 1.0,
#     'gmax': 0.4,
#     'threshold': -55.0,
#     'class': 'PowerGPotGPot',
#     'reverse': 0.0,
#     'label': 'synapse_Pdf-LaN-1-L_Pdf-LaN-2-L'}),
#   ('Rh6-PR-7-L',
#    {'phi': 0.001,
#     'initn': 0.3525,
#     'g_Ca': 4.0,
#     'offset': 0.0,
#     'V_L': -40.0,
#     'V_Ca': 120.0,
#     'Neurotransmitter': 'AchT',
#     'Type': 'Input',
#     'Side': 'Left',
#     'V_K': -80.0,
#     'name': 'MorrisLecar',
#     'initV': -46.08,
#     'g_L': 3.0,
#     'class': 'MorrisLecar',
#     'V1': -20.0,
#     'V2': 50.0,
#     'V3': -40.0,
#     'V4': 20.0,
#     'g_K': 16.0,
#     'label': 'Rh6-PR-7-L'}),
#   ('synapse_Rh5-PR-3-R_glu-lOLP-R',
#    {'slope': 0.02,
#     'saturation': 0.4,
#     'name': 'PowerGPotGPot',
#     'power': 1.0,
#     'gmax': 0.4,
#     'threshold': -55.0,
#     'class': 'PowerGPotGPot',
#     'reverse': 0.0,
#     'label': 'synapse_Rh5-PR-3-R_glu-lOLP-R'}),
#   ('synapse_Rh5-PR-3-R_5th-LaN-R',
#    {'slope': 0.02,
#     'saturation': 0.4,
#     'name': 'PowerGPotGPot',
#     'power': 1.0,
#     'gmax': 0.4,
#     'threshold': -55.0,
#     'class': 'PowerGPotGPot',
#     'reverse': 0.0,
#     'label': 'synapse_Rh5-PR-3-R_5th-LaN-R'}),
#   ('synapse_Phasic-VPN-R_glu-lOLP-R',
#    {'slope': 0.02,
#     'saturation': 0.4,
#     'name': 'PowerGPotGPot',
#     'power': 1.0,
#     'gmax': 0.4,
#     'threshold': -55.0,
#     'class': 'PowerGPotGPot',
#     'reverse': -80.0,
#     'label': 'synapse_Phasic-VPN-R_glu-lOLP-R'}),
#   ('synapse_nc-LaN-1-R_cha-lOLP-R',
#    {'slope': 0.02,
#     'saturation': 0.4,
#     'name': 'PowerGPotGPot',
#     'power': 1.0,
#     'gmax': 0.4,
#     'threshold': -55.0,
#     'class': 'PowerGPotGPot',
#     'reverse': 0.0,
#     'label': 'synapse_nc-LaN-1-R_cha-lOLP-R'}),
#   ('Rh6-PR-7-R',
#    {'phi': 0.001,
#     'initn': 0.3525,
#     'g_Ca': 4.0,
#     'offset': 0.0,
#     'V_L': -40.0,
#     'V_Ca': 120.0,
#     'Neurotransmitter': 'AchT',
#     'Type': 'Input',
#     'Side': 'Right',
#     'V_K': -80.0,
#     'name': 'MorrisLecar',
#     'initV': -46.08,
#     'g_L': 3.0,
#     'class': 'MorrisLecar',
#     'V1': -20.0,
#     'V2': 50.0,
#     'V3': -40.0,
#     'V4': 20.0,
#     'g_K': 16.0,
#     'label': 'Rh6-PR-7-R'}),
#   ('synapse_Rh6-PR-9-L_Rh6-PR-2-L',
#    {'slope': 0.02,
#     'saturation': 0.4,
#     'name': 'PowerGPotGPot',
#     'power': 1.0,
#     'gmax': 0.4,
#     'threshold': -55.0,
#     'class': 'PowerGPotGPot',
#     'reverse': 0.0,
#     'label': 'synapse_Rh6-PR-9-L_Rh6-PR-2-L'}),
#   ('synapse_cha-lOLP-R_Pdf-LaN-3-R',
#    {'slope': 0.02,
#     'saturation': 0.4,
#     'name': 'PowerGPotGPot',
#     'power': 1.0,
#     'gmax': 0.4,
#     'threshold': -55.0,
#     'class': 'PowerGPotGPot',
#     'reverse': 0.0,
#     'label': 'synapse_cha-lOLP-R_Pdf-LaN-3-R'}),
#   ('synapse_sVUM2mx-L_cha-lOLP-L',
#    {'slope': 0.02,
#     'saturation': 0.4,
#     'name': 'PowerGPotGPot',
#     'power': 1.0,
#     'gmax': 0.4,
#     'threshold': -55.0,
#     'class': 'PowerGPotGPot',
#     'reverse': 0.0,
#     'label': 'synapse_sVUM2mx-L_cha-lOLP-L'}),
#   ('synapse_Rh5-PR-4-R_5th-LaN-R',
#    {'slope': 0.02,
#     'saturation': 0.4,
#     'name': 'PowerGPotGPot',
#     'power': 1.0,
#     'gmax': 0.4,
#     'threshold': -55.0,
#     'class': 'PowerGPotGPot',
#     'reverse': 0.0,
#     'label': 'synapse_Rh5-PR-4-R_5th-LaN-R'}),
#   ('synapse_Rh6-PR-6-L_Pdf-LaN-3-L',
#    {'slope': 0.02,
#     'saturation': 0.4,
#     'name': 'PowerGPotGPot',
#     'power': 1.0,
#     'gmax': 0.4,
#     'threshold': -55.0,
#     'class': 'PowerGPotGPot',
#     'reverse': 0.0,
#     'label': 'synapse_Rh6-PR-6-L_Pdf-LaN-3-L'}),
#   ('synapse_cha-lOLP-R_Pdf-LaN-4-R',
#    {'slope': 0.02,
#     'saturation': 0.4,
#     'name': 'PowerGPotGPot',
#     'power': 1.0,
#     'gmax': 0.4,
#     'threshold': -55.0,
#     'class': 'PowerGPotGPot',
#     'reverse': 0.0,
#     'label': 'synapse_cha-lOLP-R_Pdf-LaN-4-R'}),
#   ('extra-glu-lOLP-R',
#    {'phi': 0.001,
#     'initn': 0.3525,
#     'g_Ca': 4.0,
#     'offset': 0.0,
#     'V_L': -40.0,
#     'V_Ca': 120.0,
#     'Neurotransmitter': 'GLUT',
#     'Type': 'VLN',
#     'Side': 'Right',
#     'V_K': -80.0,
#     'name': 'MorrisLecar',
#     'initV': -46.08,
#     'g_L': 3.0,
#     'class': 'MorrisLecar',
#     'V1': -20.0,
#     'V2': 50.0,
#     'V3': -40.0,
#     'V4': 20.0,
#     'g_K': 16.0,
#     'label': 'extra-glu-lOLP-R'}),
#   ('synapse_Rh6-PR-10-R_extra-glu-lOLP-R',
#    {'slope': 0.02,
#     'saturation': 0.4,
#     'name': 'PowerGPotGPot',
#     'power': 1.0,
#     'gmax': 0.4,
#     'threshold': -55.0,
#     'class': 'PowerGPotGPot',
#     'reverse': 0.0,
#     'label': 'synapse_Rh6-PR-10-R_extra-glu-lOLP-R'}),
#   ('synapse_sVUM2mx-R_glu-lOLP-R',
#    {'slope': 0.02,
#     'saturation': 0.4,
#     'name': 'PowerGPotGPot',
#     'power': 1.0,
#     'gmax': 0.4,
#     'threshold': -55.0,
#     'class': 'PowerGPotGPot',
#     'reverse': 0.0,
#     'label': 'synapse_sVUM2mx-R_glu-lOLP-R'}),
#   ('synapse_Rh5-PR-2-R_Phasic-VPN-R',
#    {'slope': 0.02,
#     'saturation': 0.4,
#     'name': 'PowerGPotGPot',
#     'power': 1.0,
#     'gmax': 0.4,
#     'threshold': -55.0,
#     'class': 'PowerGPotGPot',
#     'reverse': 0.0,
#     'label': 'synapse_Rh5-PR-2-R_Phasic-VPN-R'}),
#   ('synapse_Rh5-PR-6-R_nc-LaN-1-R',
#    {'slope': 0.02,
#     'saturation': 0.4,
#     'name': 'PowerGPotGPot',
#     'power': 1.0,
#     'gmax': 0.4,
#     'threshold': -55.0,
#     'class': 'PowerGPotGPot',
#     'reverse': 0.0,
#     'label': 'synapse_Rh5-PR-6-R_nc-LaN-1-R'}),
#   ('synapse_Rh5-PR-1-L_pOLP-L',
#    {'slope': 0.02,
#     'saturation': 0.4,
#     'name': 'PowerGPotGPot',
#     'power': 1.0,
#     'gmax': 0.4,
#     'threshold': -55.0,
#     'class': 'PowerGPotGPot',
#     'reverse': 0.0,
#     'label': 'synapse_Rh5-PR-1-L_pOLP-L'}),
#   ('synapse_extra-glu-lOLP-R_glu-lOLP-R',
#    {'slope': 0.02,
#     'saturation': 0.4,
#     'name': 'PowerGPotGPot',
#     'power': 1.0,
#     'gmax': 0.4,
#     'threshold': -55.0,
#     'class': 'PowerGPotGPot',
#     'reverse': -80.0,
#     'label': 'synapse_extra-glu-lOLP-R_glu-lOLP-R'}),
#   ('synapse_Rh5-PR-1-R_Pdf-LaN-4-R',
#    {'slope': 0.02,
#     'saturation': 0.4,
#     'name': 'PowerGPotGPot',
#     'power': 1.0,
#     'gmax': 0.4,
#     'threshold': -55.0,
#     'class': 'PowerGPotGPot',
#     'reverse': 0.0,
#     'label': 'synapse_Rh5-PR-1-R_Pdf-LaN-4-R'}),
#   ('synapse_SP2-1-L_Pdf-LaN-2-L',
#    {'slope': 0.02,
#     'saturation': 0.4,
#     'name': 'PowerGPotGPot',
#     'power': 1.0,
#     'gmax': 0.4,
#     'threshold': -55.0,
#     'class': 'PowerGPotGPot',
#     'reverse': 0.0,
#     'label': 'synapse_SP2-1-L_Pdf-LaN-2-L'}),
#   ('synapse_Rh6-PR-6-L_Pdf-LaN-4-L',
#    {'slope': 0.02,
#     'saturation': 0.4,
#     'name': 'PowerGPotGPot',
#     'power': 1.0,
#     'gmax': 0.4,
#     'threshold': -55.0,
#     'class': 'PowerGPotGPot',
#     'reverse': 0.0,
#     'label': 'synapse_Rh6-PR-6-L_Pdf-LaN-4-L'}),
#   ('synapse_Rh6-PR-9-L_nc-LaN-1-L',
#    {'slope': 0.02,
#     'saturation': 0.4,
#     'name': 'PowerGPotGPot',
#     'power': 1.0,
#     'gmax': 0.4,
#     'threshold': -55.0,
#     'class': 'PowerGPotGPot',
#     'reverse': 0.0,
#     'label': 'synapse_Rh6-PR-9-L_nc-LaN-1-L'}),
#   ('synapse_nc-LaN-1-R_Pdf-LaN-1-R',
#    {'slope': 0.02,
#     'saturation': 0.4,
#     'name': 'PowerGPotGPot',
#     'power': 1.0,
#     'gmax': 0.4,
#     'threshold': -55.0,
#     'class': 'PowerGPotGPot',
#     'reverse': 0.0,
#     'label': 'synapse_nc-LaN-1-R_Pdf-LaN-1-R'}),
#   ('Rh6-PR-4-R',
#    {'phi': 0.001,
#     'initn': 0.3525,
#     'g_Ca': 4.0,
#     'offset': 0.0,
#     'V_L': -40.0,
#     'V_Ca': 120.0,
#     'Neurotransmitter': 'AchT',
#     'Type': 'Input',
#     'Side': 'Right',
#     'V_K': -80.0,
#     'name': 'MorrisLecar',
#     'initV': -46.08,
#     'g_L': 3.0,
#     'class': 'MorrisLecar',
#     'V1': -20.0,
#     'V2': 50.0,
#     'V3': -40.0,
#     'V4': 20.0,
#     'g_K': 16.0,
#     'label': 'Rh6-PR-4-R'}),
#   ('synapse_Rh6-PR-8-R_glu-lOLP-R',
#    {'slope': 0.02,
#     'saturation': 0.4,
#     'name': 'PowerGPotGPot',
#     'power': 1.0,
#     'gmax': 0.4,
#     'threshold': -55.0,
#     'class': 'PowerGPotGPot',
#     'reverse': 0.0,
#     'label': 'synapse_Rh6-PR-8-R_glu-lOLP-R'}),
#   ('synapse_nc-LaN-1-L_Phasic-VPN-L',
#    {'slope': 0.02,
#     'saturation': 0.4,
#     'name': 'PowerGPotGPot',
#     'power': 1.0,
#     'gmax': 0.4,
#     'threshold': -55.0,
#     'class': 'PowerGPotGPot',
#     'reverse': 0.0,
#     'label': 'synapse_nc-LaN-1-L_Phasic-VPN-L'}),
#   ('synapse_Rh5-PR-2-L_5th-LaN-L',
#    {'slope': 0.02,
#     'saturation': 0.4,
#     'name': 'PowerGPotGPot',
#     'power': 1.0,
#     'gmax': 0.4,
#     'threshold': -55.0,
#     'class': 'PowerGPotGPot',
#     'reverse': 0.0,
#     'label': 'synapse_Rh5-PR-2-L_5th-LaN-L'}),
#   ('synapse_Rh5-PR-1-L_cha-lOLP-L',
#    {'slope': 0.02,
#     'saturation': 0.4,
#     'name': 'PowerGPotGPot',
#     'power': 1.0,
#     'gmax': 0.4,
#     'threshold': -55.0,
#     'class': 'PowerGPotGPot',
#     'reverse': 0.0,
#     'label': 'synapse_Rh5-PR-1-L_cha-lOLP-L'}),
#   ('Rh6-PR-4-L',
#    {'phi': 0.001,
#     'initn': 0.3525,
#     'g_Ca': 4.0,
#     'offset': 0.0,
#     'V_L': -40.0,
#     'V_Ca': 120.0,
#     'Neurotransmitter': 'AchT',
#     'Type': 'Input',
#     'Side': 'Left',
#     'V_K': -80.0,
#     'name': 'MorrisLecar',
#     'initV': -46.08,
#     'g_L': 3.0,
#     'class': 'MorrisLecar',
#     'V1': -20.0,
#     'V2': 50.0,
#     'V3': -40.0,
#     'V4': 20.0,
#     'g_K': 16.0,
#     'label': 'Rh6-PR-4-L'}),
#   ('synapse_sVUM2md-L_sVUM2mx-L',
#    {'slope': 0.02,
#     'saturation': 0.4,
#     'name': 'PowerGPotGPot',
#     'power': 1.0,
#     'gmax': 0.4,
#     'threshold': -55.0,
#     'class': 'PowerGPotGPot',
#     'reverse': 0.0,
#     'label': 'synapse_sVUM2md-L_sVUM2mx-L'}),
#   ('synapse_nc-LaN-1-R_Pdf-LaN-2-R',
#    {'slope': 0.02,
#     'saturation': 0.4,
#     'name': 'PowerGPotGPot',
#     'power': 1.0,
#     'gmax': 0.4,
#     'threshold': -55.0,
#     'class': 'PowerGPotGPot',
#     'reverse': 0.0,
#     'label': 'synapse_nc-LaN-1-R_Pdf-LaN-2-R'}),
#   ('synapse_Rh6-PR-5-R_PVL09-R',
#    {'slope': 0.02,
#     'saturation': 0.4,
#     'name': 'PowerGPotGPot',
#     'power': 1.0,
#     'gmax': 0.4,
#     'threshold': -55.0,
#     'class': 'PowerGPotGPot',
#     'reverse': 0.0,
#     'label': 'synapse_Rh6-PR-5-R_PVL09-R'}),
#   ('synapse_SP2-1-R_sVUM2md-R',
#    {'slope': 0.02,
#     'saturation': 0.4,
#     'name': 'PowerGPotGPot',
#     'power': 1.0,
#     'gmax': 0.4,
#     'threshold': -55.0,
#     'class': 'PowerGPotGPot',
#     'reverse': 0.0,
#     'label': 'synapse_SP2-1-R_sVUM2md-R'}),
#   ('synapse_cha-lOLP-L_sVUM2md-L',
#    {'slope': 0.02,
#     'saturation': 0.4,
#     'name': 'PowerGPotGPot',
#     'power': 1.0,
#     'gmax': 0.4,
#     'threshold': -55.0,
#     'class': 'PowerGPotGPot',
#     'reverse': 0.0,
#     'label': 'synapse_cha-lOLP-L_sVUM2md-L'}),
#   ('synapse_SP2-1-L_5th-LaN-L',
#    {'slope': 0.02,
#     'saturation': 0.4,
#     'name': 'PowerGPotGPot',
#     'power': 1.0,
#     'gmax': 0.4,
#     'threshold': -55.0,
#     'class': 'PowerGPotGPot',
#     'reverse': 0.0,
#     'label': 'synapse_SP2-1-L_5th-LaN-L'}),
#   ('synapse_Rh5-PR-2-L_Pdf-LaN-1-L',
#    {'slope': 0.02,
#     'saturation': 0.4,
#     'name': 'PowerGPotGPot',
#     'power': 1.0,
#     'gmax': 0.4,
#     'threshold': -55.0,
#     'class': 'PowerGPotGPot',
#     'reverse': 0.0,
#     'label': 'synapse_Rh5-PR-2-L_Pdf-LaN-1-L'}),
#   ('synapse_Rh5-PR-6-R_PVL09-R',
#    {'slope': 0.02,
#     'saturation': 0.4,
#     'name': 'PowerGPotGPot',
#     'power': 1.0,
#     'gmax': 0.4,
#     'threshold': -55.0,
#     'class': 'PowerGPotGPot',
#     'reverse': 0.0,
#     'label': 'synapse_Rh5-PR-6-R_PVL09-R'}),
#   ('cha-lOLP-R',
#    {'phi': 0.001,
#     'initn': 0.3525,
#     'g_Ca': 4.0,
#     'offset': 0.0,
#     'V_L': -40.0,
#     'V_Ca': 120.0,
#     'Neurotransmitter': 'AchT',
#     'Type': 'VLN',
#     'Side': 'Right',
#     'V_K': -80.0,
#     'name': 'MorrisLecar',
#     'initV': -46.08,
#     'g_L': 3.0,
#     'class': 'MorrisLecar',
#     'V1': -20.0,
#     'V2': 50.0,
#     'V3': -40.0,
#     'V4': 20.0,
#     'g_K': 16.0,
#     'label': 'cha-lOLP-R'}),
#   ('synapse_SP2-1-L_Phasic-VPN-L',
#    {'slope': 0.02,
#     'saturation': 0.4,
#     'name': 'PowerGPotGPot',
#     'power': 1.0,
#     'gmax': 0.4,
#     'threshold': -55.0,
#     'class': 'PowerGPotGPot',
#     'reverse': 0.0,
#     'label': 'synapse_SP2-1-L_Phasic-VPN-L'}),
#   ('synapse_nc-LaN-1-R_extra-glu-lOLP-R',
#    {'slope': 0.02,
#     'saturation': 0.4,
#     'name': 'PowerGPotGPot',
#     'power': 1.0,
#     'gmax': 0.4,
#     'threshold': -55.0,
#     'class': 'PowerGPotGPot',
#     'reverse': 0.0,
#     'label': 'synapse_nc-LaN-1-R_extra-glu-lOLP-R'}),
#   ('synapse_Rh6-PR-1-L_nc-LaN-2-L',
#    {'slope': 0.02,
#     'saturation': 0.4,
#     'name': 'PowerGPotGPot',
#     'power': 1.0,
#     'gmax': 0.4,
#     'threshold': -55.0,
#     'class': 'PowerGPotGPot',
#     'reverse': 0.0,
#     'label': 'synapse_Rh6-PR-1-L_nc-LaN-2-L'}),
#   ('synapse_Rh6-PR-5-R_cha-lOLP-R',
#    {'slope': 0.02,
#     'saturation': 0.4,
#     'name': 'PowerGPotGPot',
#     'power': 1.0,
#     'gmax': 0.4,
#     'threshold': -55.0,
#     'class': 'PowerGPotGPot',
#     'reverse': 0.0,
#     'label': 'synapse_Rh6-PR-5-R_cha-lOLP-R'}),
#   ('synapse_Rh5-PR-2-L_cha-lOLP-L',
#    {'slope': 0.02,
#     'saturation': 0.4,
#     'name': 'PowerGPotGPot',
#     'power': 1.0,
#     'gmax': 0.4,
#     'threshold': -55.0,
#     'class': 'PowerGPotGPot',
#     'reverse': 0.0,
#     'label': 'synapse_Rh5-PR-2-L_cha-lOLP-L'}),
#   ('synapse_extra-glu-lOLP-R_5th-LaN-R',
#    {'slope': 0.02,
#     'saturation': 0.4,
#     'name': 'PowerGPotGPot',
#     'power': 1.0,
#     'gmax': 0.4,
#     'threshold': -55.0,
#     'class': 'PowerGPotGPot',
#     'reverse': -80.0,
#     'label': 'synapse_extra-glu-lOLP-R_5th-LaN-R'}),
#   ('synapse_Rh5-PR-5-R_glu-lOLP-R',
#    {'slope': 0.02,
#     'saturation': 0.4,
#     'name': 'PowerGPotGPot',
#     'power': 1.0,
#     'gmax': 0.4,
#     'threshold': -55.0,
#     'class': 'PowerGPotGPot',
#     'reverse': 0.0,
#     'label': 'synapse_Rh5-PR-5-R_glu-lOLP-R'}),
#   ('cha-lOLP-L',
#    {'phi': 0.001,
#     'initn': 0.3525,
#     'g_Ca': 4.0,
#     'offset': 0.0,
#     'V_L': -40.0,
#     'V_Ca': 120.0,
#     'Neurotransmitter': 'AchT',
#     'Type': 'VLN',
#     'Side': 'Left',
#     'V_K': -80.0,
#     'name': 'MorrisLecar',
#     'initV': -46.08,
#     'g_L': 3.0,
#     'class': 'MorrisLecar',
#     'V1': -20.0,
#     'V2': 50.0,
#     'V3': -40.0,
#     'V4': 20.0,
#     'g_K': 16.0,
#     'label': 'cha-lOLP-L'}),
#   ('synapse_SP2-1-R_Pdf-LaN-4-R',
#    {'slope': 0.02,
#     'saturation': 0.4,
#     'name': 'PowerGPotGPot',
#     'power': 1.0,
#     'gmax': 0.4,
#     'threshold': -55.0,
#     'class': 'PowerGPotGPot',
#     'reverse': 0.0,
#     'label': 'synapse_SP2-1-R_Pdf-LaN-4-R'}),
#   ('Rh6-PR-9-L',
#    {'phi': 0.001,
#     'initn': 0.3525,
#     'g_Ca': 4.0,
#     'offset': 0.0,
#     'V_L': -40.0,
#     'V_Ca': 120.0,
#     'Neurotransmitter': 'AchT',
#     'Type': 'Input',
#     'Side': 'Left',
#     'V_K': -80.0,
#     'name': 'MorrisLecar',
#     'initV': -46.08,
#     'g_L': 3.0,
#     'class': 'MorrisLecar',
#     'V1': -20.0,
#     'V2': 50.0,
#     'V3': -40.0,
#     'V4': 20.0,
#     'g_K': 16.0,
#     'label': 'Rh6-PR-9-L'}),
#   ('synapse_5th-LaN-R_SP2-1-R',
#    {'slope': 0.02,
#     'saturation': 0.4,
#     'name': 'PowerGPotGPot',
#     'power': 1.0,
#     'gmax': 0.4,
#     'threshold': -55.0,
#     'class': 'PowerGPotGPot',
#     'reverse': 0.0,
#     'label': 'synapse_5th-LaN-R_SP2-1-R'}),
#   ('synapse_glu-lOLP-L_Pdf-LaN-4-L',
#    {'slope': 0.02,
#     'saturation': 0.4,
#     'name': 'PowerGPotGPot',
#     'power': 1.0,
#     'gmax': 0.4,
#     'threshold': -55.0,
#     'class': 'PowerGPotGPot',
#     'reverse': -80.0,
#     'label': 'synapse_glu-lOLP-L_Pdf-LaN-4-L'}),
#   ('synapse_Pdf-LaN-2-L_Pdf-LaN-4-L',
#    {'slope': 0.02,
#     'saturation': 0.4,
#     'name': 'PowerGPotGPot',
#     'power': 1.0,
#     'gmax': 0.4,
#     'threshold': -55.0,
#     'class': 'PowerGPotGPot',
#     'reverse': 0.0,
#     'label': 'synapse_Pdf-LaN-2-L_Pdf-LaN-4-L'}),
#   ('synapse_Phasic-VPN-R_5th-LaN-R',
#    {'slope': 0.02,
#     'saturation': 0.4,
#     'name': 'PowerGPotGPot',
#     'power': 1.0,
#     'gmax': 0.4,
#     'threshold': -55.0,
#     'class': 'PowerGPotGPot',
#     'reverse': -80.0,
#     'label': 'synapse_Phasic-VPN-R_5th-LaN-R'}),
#   ('synapse_Phasic-VPN-R_Phasic-VPN-R',
#    {'slope': 0.02,
#     'saturation': 0.4,
#     'name': 'PowerGPotGPot',
#     'power': 1.0,
#     'gmax': 0.4,
#     'threshold': -55.0,
#     'class': 'PowerGPotGPot',
#     'reverse': -80.0,
#     'label': 'synapse_Phasic-VPN-R_Phasic-VPN-R'}),
#   ('synapse_extra-glu-lOLP-R_Phasic-VPN-R',
#    {'slope': 0.02,
#     'saturation': 0.4,
#     'name': 'PowerGPotGPot',
#     'power': 1.0,
#     'gmax': 0.4,
#     'threshold': -55.0,
#     'class': 'PowerGPotGPot',
#     'reverse': -80.0,
#     'label': 'synapse_extra-glu-lOLP-R_Phasic-VPN-R'}),
#   ('synapse_sVUM2md-L_cha-lOLP-L',
#    {'slope': 0.02,
#     'saturation': 0.4,
#     'name': 'PowerGPotGPot',
#     'power': 1.0,
#     'gmax': 0.4,
#     'threshold': -55.0,
#     'class': 'PowerGPotGPot',
#     'reverse': 0.0,
#     'label': 'synapse_sVUM2md-L_cha-lOLP-L'}),
#   ('Rh6-PR-9-R',
#    {'phi': 0.001,
#     'initn': 0.3525,
#     'g_Ca': 4.0,
#     'offset': 0.0,
#     'V_L': -40.0,
#     'V_Ca': 120.0,
#     'Neurotransmitter': 'AchT',
#     'Type': 'Input',
#     'Side': 'Right',
#     'V_K': -80.0,
#     'name': 'MorrisLecar',
#     'initV': -46.08,
#     'g_L': 3.0,
#     'class': 'MorrisLecar',
#     'V1': -20.0,
#     'V2': 50.0,
#     'V3': -40.0,
#     'V4': 20.0,
#     'g_K': 16.0,
#     'label': 'Rh6-PR-9-R'}),
#   ('synapse_cha-lOLP-L_sVUM2mx-L',
#    {'slope': 0.02,
#     'saturation': 0.4,
#     'name': 'PowerGPotGPot',
#     'power': 1.0,
#     'gmax': 0.4,
#     'threshold': -55.0,
#     'class': 'PowerGPotGPot',
#     'reverse': 0.0,
#     'label': 'synapse_cha-lOLP-L_sVUM2mx-L'}),
#   ('synapse_Rh6-PR-4-L_Pdf-LaN-1-L',
#    {'slope': 0.02,
#     'saturation': 0.4,
#     'name': 'PowerGPotGPot',
#     'power': 1.0,
#     'gmax': 0.4,
#     'threshold': -55.0,
#     'class': 'PowerGPotGPot',
#     'reverse': 0.0,
#     'label': 'synapse_Rh6-PR-4-L_Pdf-LaN-1-L'}),
#   ('Rh6-PR-1-R',
#    {'phi': 0.001,
#     'initn': 0.3525,
#     'g_Ca': 4.0,
#     'offset': 0.0,
#     'V_L': -40.0,
#     'V_Ca': 120.0,
#     'Neurotransmitter': 'AchT',
#     'Type': 'Input',
#     'Side': 'Right',
#     'V_K': -80.0,
#     'name': 'MorrisLecar',
#     'initV': -46.08,
#     'g_L': 3.0,
#     'class': 'MorrisLecar',
#     'V1': -20.0,
#     'V2': 50.0,
#     'V3': -40.0,
#     'V4': 20.0,
#     'g_K': 16.0,
#     'label': 'Rh6-PR-1-R'}),
#   ('synapse_cha-lOLP-R_nc-LaN-1-R',
#    {'slope': 0.02,
#     'saturation': 0.4,
#     'name': 'PowerGPotGPot',
#     'power': 1.0,
#     'gmax': 0.4,
#     'threshold': -55.0,
#     'class': 'PowerGPotGPot',
#     'reverse': 0.0,
#     'label': 'synapse_cha-lOLP-R_nc-LaN-1-R'}),
#   ('Rh6-PR-2-R',
#    {'phi': 0.001,
#     'initn': 0.3525,
#     'g_Ca': 4.0,
#     'offset': 0.0,
#     'V_L': -40.0,
#     'V_Ca': 120.0,
#     'Neurotransmitter': 'AchT',
#     'Type': 'Input',
#     'Side': 'Right',
#     'V_K': -80.0,
#     'name': 'MorrisLecar',
#     'initV': -46.08,
#     'g_L': 3.0,
#     'class': 'MorrisLecar',
#     'V1': -20.0,
#     'V2': 50.0,
#     'V3': -40.0,
#     'V4': 20.0,
#     'g_K': 16.0,
#     'label': 'Rh6-PR-2-R'}),
#   ('synapse_Rh6-PR-9-L_glu-lOLP-L',
#    {'slope': 0.02,
#     'saturation': 0.4,
#     'name': 'PowerGPotGPot',
#     'power': 1.0,
#     'gmax': 0.4,
#     'threshold': -55.0,
#     'class': 'PowerGPotGPot',
#     'reverse': 0.0,
#     'label': 'synapse_Rh6-PR-9-L_glu-lOLP-L'}),
#   ('Rh6-PR-2-L',
#    {'phi': 0.001,
#     'initn': 0.3525,
#     'g_Ca': 4.0,
#     'offset': 0.0,
#     'V_L': -40.0,
#     'V_Ca': 120.0,
#     'Neurotransmitter': 'AchT',
#     'Type': 'Input',
#     'Side': 'Left',
#     'V_K': -80.0,
#     'name': 'MorrisLecar',
#     'initV': -46.08,
#     'g_L': 3.0,
#     'class': 'MorrisLecar',
#     'V1': -20.0,
#     'V2': 50.0,
#     'V3': -40.0,
#     'V4': 20.0,
#     'g_K': 16.0,
#     'label': 'Rh6-PR-2-L'}),
#   ('synapse_Rh5-PR-1-R_Pdf-LaN-2-R',
#    {'slope': 0.02,
#     'saturation': 0.4,
#     'name': 'PowerGPotGPot',
#     'power': 1.0,
#     'gmax': 0.4,
#     'threshold': -55.0,
#     'class': 'PowerGPotGPot',
#     'reverse': 0.0,
#     'label': 'synapse_Rh5-PR-1-R_Pdf-LaN-2-R'}),
#   ('Rh6-PR-1-L',
#    {'phi': 0.001,
#     'initn': 0.3525,
#     'g_Ca': 4.0,
#     'offset': 0.0,
#     'V_L': -40.0,
#     'V_Ca': 120.0,
#     'Neurotransmitter': 'AchT',
#     'Type': 'Input',
#     'Side': 'Left',
#     'V_K': -80.0,
#     'name': 'MorrisLecar',
#     'initV': -46.08,
#     'g_L': 3.0,
#     'class': 'MorrisLecar',
#     'V1': -20.0,
#     'V2': 50.0,
#     'V3': -40.0,
#     'V4': 20.0,
#     'g_K': 16.0,
#     'label': 'Rh6-PR-1-L'}),
#   ('synapse_Rh5-PR-1-R_Pdf-LaN-1-R',
#    {'slope': 0.02,
#     'saturation': 0.4,
#     'name': 'PowerGPotGPot',
#     'power': 1.0,
#     'gmax': 0.4,
#     'threshold': -55.0,
#     'class': 'PowerGPotGPot',
#     'reverse': 0.0,
#     'label': 'synapse_Rh5-PR-1-R_Pdf-LaN-1-R'}),
#   ('synapse_sVUM2md-R_pOLP-R',
#    {'slope': 0.02,
#     'saturation': 0.4,
#     'name': 'PowerGPotGPot',
#     'power': 1.0,
#     'gmax': 0.4,
#     'threshold': -55.0,
#     'class': 'PowerGPotGPot',
#     'reverse': 0.0,
#     'label': 'synapse_sVUM2md-R_pOLP-R'}),
#   ('synapse_glu-lOLP-L_PVL09-L',
#    {'slope': 0.02,
#     'saturation': 0.4,
#     'name': 'PowerGPotGPot',
#     'power': 1.0,
#     'gmax': 0.4,
#     'threshold': -55.0,
#     'class': 'PowerGPotGPot',
#     'reverse': -80.0,
#     'label': 'synapse_glu-lOLP-L_PVL09-L'}),
#   ('synapse_Rh5-PR-6-R_extra-glu-lOLP-R',
#    {'slope': 0.02,
#     'saturation': 0.4,
#     'name': 'PowerGPotGPot',
#     'power': 1.0,
#     'gmax': 0.4,
#     'threshold': -55.0,
#     'class': 'PowerGPotGPot',
#     'reverse': 0.0,
#     'label': 'synapse_Rh5-PR-6-R_extra-glu-lOLP-R'}),
#   ('synapse_Rh5-PR-4-L_pOLP-L',
#    {'slope': 0.02,
#     'saturation': 0.4,
#     'name': 'PowerGPotGPot',
#     'power': 1.0,
#     'gmax': 0.4,
#     'threshold': -55.0,
#     'class': 'PowerGPotGPot',
#     'reverse': 0.0,
#     'label': 'synapse_Rh5-PR-4-L_pOLP-L'}),
#   ('synapse_cha-lOLP-R_Pdf-LaN-2-R',
#    {'slope': 0.02,
#     'saturation': 0.4,
#     'name': 'PowerGPotGPot',
#     'power': 1.0,
#     'gmax': 0.4,
#     'threshold': -55.0,
#     'class': 'PowerGPotGPot',
#     'reverse': 0.0,
#     'label': 'synapse_cha-lOLP-R_Pdf-LaN-2-R'}),
#   ('synapse_nc-LaN-1-L_PVL09-L',
#    {'slope': 0.02,
#     'saturation': 0.4,
#     'name': 'PowerGPotGPot',
#     'power': 1.0,
#     'gmax': 0.4,
#     'threshold': -55.0,
#     'class': 'PowerGPotGPot',
#     'reverse': 0.0,
#     'label': 'synapse_nc-LaN-1-L_PVL09-L'}),
#   ('synapse_cha-lOLP-R_Pdf-LaN-1-R',
#    {'slope': 0.02,
#     'saturation': 0.4,
#     'name': 'PowerGPotGPot',
#     'power': 1.0,
#     'gmax': 0.4,
#     'threshold': -55.0,
#     'class': 'PowerGPotGPot',
#     'reverse': 0.0,
#     'label': 'synapse_cha-lOLP-R_Pdf-LaN-1-R'}),
#   ('synapse_Rh6-PR-1-L_cha-lOLP-L',
#    {'slope': 0.02,
#     'saturation': 0.4,
#     'name': 'PowerGPotGPot',
#     'power': 1.0,
#     'gmax': 0.4,
#     'threshold': -55.0,
#     'class': 'PowerGPotGPot',
#     'reverse': 0.0,
#     'label': 'synapse_Rh6-PR-1-L_cha-lOLP-L'}),
#   ('synapse_Rh5-PR-2-R_pOLP-R',
#    {'slope': 0.02,
#     'saturation': 0.4,
#     'name': 'PowerGPotGPot',
#     'power': 1.0,
#     'gmax': 0.4,
#     'threshold': -55.0,
#     'class': 'PowerGPotGPot',
#     'reverse': 0.0,
#     'label': 'synapse_Rh5-PR-2-R_pOLP-R'}),
#   ('synapse_nc-LaN-1-R_Pdf-LaN-4-R',
#    {'slope': 0.02,
#     'saturation': 0.4,
#     'name': 'PowerGPotGPot',
#     'power': 1.0,
#     'gmax': 0.4,
#     'threshold': -55.0,
#     'class': 'PowerGPotGPot',
#     'reverse': 0.0,
#     'label': 'synapse_nc-LaN-1-R_Pdf-LaN-4-R'}),
#   ('synapse_Rh6-PR-6-L_Pdf-LaN-1-L',
#    {'slope': 0.02,
#     'saturation': 0.4,
#     'name': 'PowerGPotGPot',
#     'power': 1.0,
#     'gmax': 0.4,
#     'threshold': -55.0,
#     'class': 'PowerGPotGPot',
#     'reverse': 0.0,
#     'label': 'synapse_Rh6-PR-6-L_Pdf-LaN-1-L'}),
#   ('synapse_Rh6-PR-6-L_Pdf-LaN-2-L',
#    {'slope': 0.02,
#     'saturation': 0.4,
#     'name': 'PowerGPotGPot',
#     'power': 1.0,
#     'gmax': 0.4,
#     'threshold': -55.0,
#     'class': 'PowerGPotGPot',
#     'reverse': 0.0,
#     'label': 'synapse_Rh6-PR-6-L_Pdf-LaN-2-L'}),
#   ('synapse_Rh6-PR-7-R_Rh6-PR-2-R',
#    {'slope': 0.02,
#     'saturation': 0.4,
#     'name': 'PowerGPotGPot',
#     'power': 1.0,
#     'gmax': 0.4,
#     'threshold': -55.0,
#     'class': 'PowerGPotGPot',
#     'reverse': 0.0,
#     'label': 'synapse_Rh6-PR-7-R_Rh6-PR-2-R'}),
#   ('synapse_Rh6-PR-3-L_Pdf-LaN-4-L',
#    {'slope': 0.02,
#     'saturation': 0.4,
#     'name': 'PowerGPotGPot',
#     'power': 1.0,
#     'gmax': 0.4,
#     'threshold': -55.0,
#     'class': 'PowerGPotGPot',
#     'reverse': 0.0,
#     'label': 'synapse_Rh6-PR-3-L_Pdf-LaN-4-L'}),
#   ('synapse_cha-lOLP-R_SP2-1-R',
#    {'slope': 0.02,
#     'saturation': 0.4,
#     'name': 'PowerGPotGPot',
#     'power': 1.0,
#     'gmax': 0.4,
#     'threshold': -55.0,
#     'class': 'PowerGPotGPot',
#     'reverse': 0.0,
#     'label': 'synapse_cha-lOLP-R_SP2-1-R'}),
#   ('synapse_Rh6-PR-3-L_Pdf-LaN-1-L',
#    {'slope': 0.02,
#     'saturation': 0.4,
#     'name': 'PowerGPotGPot',
#     'power': 1.0,
#     'gmax': 0.4,
# ...
#   ('synapse_nc-LaN-2-L_nc-LaN-1-L',
#    'nc-LaN-1-L',
#    {'id': '657', 'weight': nan}),
#   ('pOLP-L', 'synapse_pOLP-L_PVL09-L', {'id': '658', 'weight': 24.0}),
#   ('pOLP-L', 'synapse_pOLP-L_nc-LaN-2-L', {'id': '659', 'weight': 1.0}),
#   ('synapse_Rh5-PR-3-R_nc-LaN-2-R',
#    'nc-LaN-2-R',
#    {'id': '660', 'weight': nan}),
#   ('synapse_Rh6-PR-5-L_Pdf-LaN-3-L',
#    'Pdf-LaN-3-L',
#    {'id': '661', 'weight': nan}),
#   ('synapse_Rh5-PR-6-R_Pdf-LaN-1-R',
#    'Pdf-LaN-1-R',
#    {'id': '662', 'weight': nan}),
#   ('synapse_Phasic-VPN-L_Pdf-LaN-4-L',
#    'Pdf-LaN-4-L',
#    {'id': '663', 'weight': nan}),
#   ('synapse_sVUM2mx-L_PVL09-L', 'PVL09-L', {'id': '664', 'weight': nan}),
#   ('synapse_Rh6-PR-7-R_Pdf-LaN-4-R',
#    'Pdf-LaN-4-R',
#    {'id': '665', 'weight': nan}),
#   ('synapse_Rh5-PR-2-R_Pdf-LaN-3-R',
#    'Pdf-LaN-3-R',
#    {'id': '666', 'weight': nan}),
#   ('pOLP-R', 'synapse_pOLP-R_PVL09-R', {'id': '667', 'weight': 9.0}),
#   ('synapse_glu-lOLP-R_cha-lOLP-R',
#    'cha-lOLP-R',
#    {'id': '668', 'weight': nan}),
#   ('synapse_SP2-1-L_glu-lOLP-L', 'glu-lOLP-L', {'id': '669', 'weight': nan}),
#   ('sVUM2md-L', 'synapse_sVUM2md-L_pOLP-L', {'id': '670', 'weight': 1.0}),
#   ('sVUM2md-L', 'synapse_sVUM2md-L_sVUM2mx-L', {'id': '671', 'weight': 2.0}),
#   ('sVUM2md-L', 'synapse_sVUM2md-L_cha-lOLP-L', {'id': '672', 'weight': 12.0}),
#   ('sVUM2md-L', 'synapse_sVUM2md-L_glu-lOLP-L', {'id': '673', 'weight': 16.0}),
#   ('synapse_Rh5-PR-3-R_cha-lOLP-R',
#    'cha-lOLP-R',
#    {'id': '674', 'weight': nan}),
#   ('glu-lOLP-L',
#    'synapse_glu-lOLP-L_Pdf-LaN-4-L',
#    {'id': '675', 'weight': 3.0}),
#   ('glu-lOLP-L',
#    'synapse_glu-lOLP-L_Pdf-LaN-2-L',
#    {'id': '676', 'weight': 8.0}),
#   ('glu-lOLP-L',
#    'synapse_glu-lOLP-L_nc-LaN-1-L',
#    {'id': '677', 'weight': 31.0}),
#   ('glu-lOLP-L',
#    'synapse_glu-lOLP-L_cha-lOLP-L',
#    {'id': '678', 'weight': 20.0}),
#   ('glu-lOLP-L',
#    'synapse_glu-lOLP-L_Rh6-PR-7-L',
#    {'id': '679', 'weight': 1.0}),
#   ('glu-lOLP-L', 'synapse_glu-lOLP-L_PVL09-L', {'id': '680', 'weight': 30.0}),
#   ('glu-lOLP-L', 'synapse_glu-lOLP-L_sVUM2mx-L', {'id': '681', 'weight': 3.0}),
#   ('glu-lOLP-L',
#    'synapse_glu-lOLP-L_glu-lOLP-L',
#    {'id': '682', 'weight': 4.0}),
#   ('glu-lOLP-L', 'synapse_glu-lOLP-L_5th-LaN-L', {'id': '683', 'weight': 8.0}),
#   ('glu-lOLP-L',
#    'synapse_glu-lOLP-L_Pdf-LaN-3-L',
#    {'id': '684', 'weight': 9.0}),
#   ('glu-lOLP-L', 'synapse_glu-lOLP-L_SP2-1-L', {'id': '685', 'weight': 1.0}),
#   ('glu-lOLP-L',
#    'synapse_glu-lOLP-L_Pdf-LaN-1-L',
#    {'id': '686', 'weight': 3.0}),
#   ('glu-lOLP-L', 'synapse_glu-lOLP-L_pOLP-L', {'id': '687', 'weight': 2.0}),
#   ('glu-lOLP-L',
#    'synapse_glu-lOLP-L_Phasic-VPN-L',
#    {'id': '688', 'weight': 21.0}),
#   ('glu-lOLP-L',
#    'synapse_glu-lOLP-L_nc-LaN-2-L',
#    {'id': '689', 'weight': 1.0}),
#   ('glu-lOLP-L', 'synapse_glu-lOLP-L_sVUM2md-L', {'id': '690', 'weight': 3.0}),
#   ('synapse_Rh5-PR-1-L_Pdf-LaN-1-L',
#    'Pdf-LaN-1-L',
#    {'id': '691', 'weight': nan}),
#   ('synapse_Rh5-PR-5-R_Pdf-LaN-2-R',
#    'Pdf-LaN-2-R',
#    {'id': '692', 'weight': nan}),
#   ('synapse_nc-LaN-2-R_5th-LaN-R', '5th-LaN-R', {'id': '693', 'weight': nan}),
#   ('synapse_Rh5-PR-1-L_Pdf-LaN-2-L',
#    'Pdf-LaN-2-L',
#    {'id': '694', 'weight': nan}),
#   ('synapse_Phasic-VPN-L_nc-LaN-1-L',
#    'nc-LaN-1-L',
#    {'id': '695', 'weight': nan}),
#   ('SP2-1-L', 'synapse_SP2-1-L_nc-LaN-1-L', {'id': '696', 'weight': 3.0}),
#   ('SP2-1-L', 'synapse_SP2-1-L_Phasic-VPN-L', {'id': '697', 'weight': 4.0}),
#   ('SP2-1-L', 'synapse_SP2-1-L_nc-LaN-2-L', {'id': '698', 'weight': 2.0}),
#   ('SP2-1-L', 'synapse_SP2-1-L_sVUM2mx-L', {'id': '699', 'weight': 1.0}),
#   ('SP2-1-L', 'synapse_SP2-1-L_Pdf-LaN-4-L', {'id': '700', 'weight': 1.0}),
#   ('SP2-1-L', 'synapse_SP2-1-L_5th-LaN-L', {'id': '701', 'weight': 1.0}),
#   ('SP2-1-L', 'synapse_SP2-1-L_cha-lOLP-L', {'id': '702', 'weight': 7.0}),
#   ('SP2-1-L', 'synapse_SP2-1-L_Pdf-LaN-2-L', {'id': '703', 'weight': 3.0}),
#   ('SP2-1-L', 'synapse_SP2-1-L_glu-lOLP-L', {'id': '704', 'weight': 11.0}),
#   ('synapse_cha-lOLP-L_nc-LaN-2-L',
#    'nc-LaN-2-L',
#    {'id': '705', 'weight': nan}),
#   ('synapse_Phasic-VPN-L_nc-LaN-2-L',
#    'nc-LaN-2-L',
#    {'id': '706', 'weight': nan}),
#   ('synapse_Rh6-PR-10-R_cha-lOLP-R',
#    'cha-lOLP-R',
#    {'id': '707', 'weight': nan}),
#   ('glu-lOLP-R', 'synapse_glu-lOLP-R_PVL09-R', {'id': '708', 'weight': 44.0}),
#   ('glu-lOLP-R',
#    'synapse_glu-lOLP-R_cha-lOLP-R',
#    {'id': '709', 'weight': 28.0}),
#   ('glu-lOLP-R',
#    'synapse_glu-lOLP-R_Phasic-VPN-R',
#    {'id': '710', 'weight': 35.0}),
#   ('glu-lOLP-R',
#    'synapse_glu-lOLP-R_Pdf-LaN-2-R',
#    {'id': '711', 'weight': 6.0}),
#   ('glu-lOLP-R', 'synapse_glu-lOLP-R_sVUM2md-R', {'id': '712', 'weight': 3.0}),
#   ('glu-lOLP-R',
#    'synapse_glu-lOLP-R_Pdf-LaN-3-R',
#    {'id': '713', 'weight': 6.0}),
#   ('glu-lOLP-R',
#    'synapse_glu-lOLP-R_Pdf-LaN-1-R',
#    {'id': '714', 'weight': 7.0}),
#   ('glu-lOLP-R',
#    'synapse_glu-lOLP-R_nc-LaN-2-R',
#    {'id': '715', 'weight': 6.0}),
#   ('glu-lOLP-R',
#    'synapse_glu-lOLP-R_Pdf-LaN-4-R',
#    {'id': '716', 'weight': 7.0}),
#   ('glu-lOLP-R', 'synapse_glu-lOLP-R_sVUM2mx-R', {'id': '717', 'weight': 1.0}),
#   ('glu-lOLP-R',
#    'synapse_glu-lOLP-R_glu-lOLP-R',
#    {'id': '718', 'weight': 1.0}),
#   ('glu-lOLP-R',
#    'synapse_glu-lOLP-R_extra-glu-lOLP-R',
#    {'id': '719', 'weight': 32.0}),
#   ('glu-lOLP-R', 'synapse_glu-lOLP-R_5th-LaN-R', {'id': '720', 'weight': 4.0}),
#   ('glu-lOLP-R',
#    'synapse_glu-lOLP-R_nc-LaN-1-R',
#    {'id': '721', 'weight': 25.0}),
#   ('synapse_glu-lOLP-R_Pdf-LaN-4-R',
#    'Pdf-LaN-4-R',
#    {'id': '722', 'weight': nan}),
#   ('synapse_Rh6-PR-9-L_Pdf-LaN-1-L',
#    'Pdf-LaN-1-L',
#    {'id': '723', 'weight': nan}),
#   ('synapse_PVL09-L_PVL09-L', 'PVL09-L', {'id': '724', 'weight': nan}),
#   ('synapse_glu-lOLP-R_5th-LaN-R', '5th-LaN-R', {'id': '725', 'weight': nan}),
#   ('synapse_Rh5-PR-3-R_nc-LaN-1-R',
#    'nc-LaN-1-R',
#    {'id': '726', 'weight': nan}),
#   ('synapse_Rh6-PR-9-R_Pdf-LaN-1-R',
#    'Pdf-LaN-1-R',
#    {'id': '727', 'weight': nan}),
#   ('synapse_Rh5-PR-4-L_PVL09-L', 'PVL09-L', {'id': '728', 'weight': nan}),
#   ('synapse_Rh5-PR-6-R_Pdf-LaN-2-R',
#    'Pdf-LaN-2-R',
#    {'id': '729', 'weight': nan}),
#   ('Pdf-LaN-1-L',
#    'synapse_Pdf-LaN-1-L_Pdf-LaN-2-L',
#    {'id': '730', 'weight': 1.0}),
#   ('Pdf-LaN-1-L',
#    'synapse_Pdf-LaN-1-L_Pdf-LaN-4-L',
#    {'id': '731', 'weight': 2.0}),
#   ('Pdf-LaN-1-L',
#    'synapse_Pdf-LaN-1-L_Pdf-LaN-3-L',
#    {'id': '732', 'weight': 1.0}),
#   ('synapse_Rh5-PR-6-R_Pdf-LaN-4-R',
#    'Pdf-LaN-4-R',
#    {'id': '733', 'weight': nan}),
#   ('Pdf-LaN-2-L',
#    'synapse_Pdf-LaN-2-L_Pdf-LaN-3-L',
#    {'id': '734', 'weight': 2.0}),
#   ('Pdf-LaN-2-L',
#    'synapse_Pdf-LaN-2-L_Pdf-LaN-4-L',
#    {'id': '735', 'weight': 1.0}),
#   ('Pdf-LaN-2-L',
#    'synapse_Pdf-LaN-2-L_Pdf-LaN-1-L',
#    {'id': '736', 'weight': 2.0}),
#   ('synapse_Rh6-PR-2-R_glu-lOLP-R',
#    'glu-lOLP-R',
#    {'id': '737', 'weight': nan}),
#   ('synapse_Rh6-PR-8-R_Pdf-LaN-1-R',
#    'Pdf-LaN-1-R',
#    {'id': '738', 'weight': nan}),
#   ('synapse_Phasic-VPN-L_Pdf-LaN-1-L',
#    'Pdf-LaN-1-L',
#    {'id': '739', 'weight': nan}),
#   ('synapse_cha-lOLP-L_PVL09-L', 'PVL09-L', {'id': '740', 'weight': nan}),
#   ('synapse_Rh6-PR-1-L_Pdf-LaN-4-L',
#    'Pdf-LaN-4-L',
#    {'id': '741', 'weight': nan}),
#   ('synapse_Rh6-PR-7-R_Pdf-LaN-1-R',
#    'Pdf-LaN-1-R',
#    {'id': '742', 'weight': nan}),
#   ('synapse_nc-LaN-1-L_glu-lOLP-L',
#    'glu-lOLP-L',
#    {'id': '743', 'weight': nan}),
#   ('synapse_Rh6-PR-7-R_Pdf-LaN-2-R',
#    'Pdf-LaN-2-R',
#    {'id': '744', 'weight': nan}),
#   ('synapse_Rh5-PR-3-R_extra-glu-lOLP-R',
#    'extra-glu-lOLP-R',
#    {'id': '745', 'weight': nan}),
#   ('synapse_Rh6-PR-4-L_glu-lOLP-L',
#    'glu-lOLP-L',
#    {'id': '746', 'weight': nan}),
#   ('synapse_Rh6-PR-1-L_Pdf-LaN-3-L',
#    'Pdf-LaN-3-L',
#    {'id': '747', 'weight': nan}),
#   ('synapse_nc-LaN-1-L_nc-LaN-2-L',
#    'nc-LaN-2-L',
#    {'id': '748', 'weight': nan}),
#   ('synapse_Rh6-PR-5-L_Pdf-LaN-4-L',
#    'Pdf-LaN-4-L',
#    {'id': '749', 'weight': nan}),
#   ('synapse_glu-lOLP-R_Pdf-LaN-2-R',
#    'Pdf-LaN-2-R',
#    {'id': '750', 'weight': nan}),
#   ('synapse_Rh6-PR-2-R_Pdf-LaN-1-R',
#    'Pdf-LaN-1-R',
#    {'id': '751', 'weight': nan}),
#   ('synapse_glu-lOLP-R_Pdf-LaN-1-R',
#    'Pdf-LaN-1-R',
#    {'id': '752', 'weight': nan}),
#   ('synapse_sVUM2md-R_glu-lOLP-R', 'glu-lOLP-R', {'id': '753', 'weight': nan}),
#   ('synapse_Rh5-PR-2-R_Pdf-LaN-4-R',
#    'Pdf-LaN-4-R',
#    {'id': '754', 'weight': nan}),
#   ('synapse_Phasic-VPN-L_Pdf-LaN-3-L',
#    'Pdf-LaN-3-L',
#    {'id': '755', 'weight': nan}),
#   ('synapse_Rh5-PR-4-L_Pdf-LaN-3-L',
#    'Pdf-LaN-3-L',
#    {'id': '756', 'weight': nan}),
#   ('synapse_Phasic-VPN-L_Pdf-LaN-2-L',
#    'Pdf-LaN-2-L',
#    {'id': '757', 'weight': nan}),
#   ('synapse_Rh5-PR-1-L_Pdf-LaN-4-L',
#    'Pdf-LaN-4-L',
#    {'id': '758', 'weight': nan}),
#   ('synapse_SP2-1-R_cha-lOLP-R', 'cha-lOLP-R', {'id': '759', 'weight': nan}),
#   ('synapse_Rh5-PR-4-L_Pdf-LaN-4-L',
#    'Pdf-LaN-4-L',
#    {'id': '760', 'weight': nan}),
#   ('synapse_Rh5-PR-6-R_cha-lOLP-R',
#    'cha-lOLP-R',
#    {'id': '761', 'weight': nan}),
#   ('synapse_Rh6-PR-5-L_glu-lOLP-L',
#    'glu-lOLP-L',
#    {'id': '762', 'weight': nan}),
#   ('synapse_Rh5-PR-5-R_Pdf-LaN-1-R',
#    'Pdf-LaN-1-R',
#    {'id': '763', 'weight': nan}),
#   ('synapse_Rh6-PR-10-R_glu-lOLP-R',
#    'glu-lOLP-R',
#    {'id': '764', 'weight': nan}),
#   ('synapse_5th-LaN-R_PVL09-R', 'PVL09-R', {'id': '765', 'weight': nan}),
#   ('synapse_Rh5-PR-4-R_extra-glu-lOLP-R',
#    'extra-glu-lOLP-R',
#    {'id': '766', 'weight': nan}),
#   ('synapse_SP2-1-L_cha-lOLP-L', 'cha-lOLP-L', {'id': '767', 'weight': nan}),
#   ('synapse_Rh5-PR-2-R_glu-lOLP-R',
#    'glu-lOLP-R',
#    {'id': '768', 'weight': nan}),
#   ('synapse_glu-lOLP-L_sVUM2md-L', 'sVUM2md-L', {'id': '769', 'weight': nan}),
#   ('synapse_Rh5-PR-4-L_Pdf-LaN-1-L',
#    'Pdf-LaN-1-L',
#    {'id': '770', 'weight': nan}),
#   ('synapse_glu-lOLP-R_Phasic-VPN-R',
#    'Phasic-VPN-R',
#    {'id': '771', 'weight': nan}),
#   ('synapse_Rh6-PR-7-R_cha-lOLP-R',
#    'cha-lOLP-R',
#    {'id': '772', 'weight': nan}),
#   ('synapse_Rh5-PR-4-L_Pdf-LaN-2-L',
#    'Pdf-LaN-2-L',
#    {'id': '773', 'weight': nan}),
#   ('synapse_Rh5-PR-2-R_Pdf-LaN-2-R',
#    'Pdf-LaN-2-R',
#    {'id': '774', 'weight': nan}),
#   ('synapse_Rh6-PR-2-R_extra-glu-lOLP-R',
#    'extra-glu-lOLP-R',
#    {'id': '775', 'weight': nan}),
#   ('synapse_cha-lOLP-R_Phasic-VPN-R',
#    'Phasic-VPN-R',
#    {'id': '776', 'weight': nan}),
#   ('synapse_Rh5-PR-4-L_cha-lOLP-L',
#    'cha-lOLP-L',
#    {'id': '777', 'weight': nan}),
#   ('synapse_SP2-1-R_sVUM2mx-R', 'sVUM2mx-R', {'id': '778', 'weight': nan}),
#   ('synapse_Rh6-PR-3-R_Pdf-LaN-1-R',
#    'Pdf-LaN-1-R',
#    {'id': '779', 'weight': nan}),
#   ('sVUM2mx-L', 'synapse_sVUM2mx-L_5th-LaN-L', {'id': '780', 'weight': 2.0}),
#   ('sVUM2mx-L', 'synapse_sVUM2mx-L_sVUM2md-L', {'id': '781', 'weight': 2.0}),
#   ('sVUM2mx-L', 'synapse_sVUM2mx-L_Pdf-LaN-1-L', {'id': '782', 'weight': 2.0}),
#   ('sVUM2mx-L', 'synapse_sVUM2mx-L_cha-lOLP-L', {'id': '783', 'weight': 17.0}),
#   ('sVUM2mx-L', 'synapse_sVUM2mx-L_PVL09-L', {'id': '784', 'weight': 2.0}),
#   ('sVUM2mx-L', 'synapse_sVUM2mx-L_glu-lOLP-L', {'id': '785', 'weight': 24.0}),
#   ('sVUM2mx-L', 'synapse_sVUM2mx-L_SP2-1-L', {'id': '786', 'weight': 2.0}),
#   ('sVUM2mx-L',
#    'synapse_sVUM2mx-L_Phasic-VPN-L',
#    {'id': '787', 'weight': 4.0}),
#   ('synapse_Rh6-PR-9-R_Pdf-LaN-4-R',
#    'Pdf-LaN-4-R',
#    {'id': '788', 'weight': nan}),
#   ('synapse_nc-LaN-1-R_Phasic-VPN-R',
#    'Phasic-VPN-R',
#    {'id': '789', 'weight': nan}),
#   ('synapse_Rh6-PR-8-L_cha-lOLP-L',
#    'cha-lOLP-L',
#    {'id': '790', 'weight': nan}),
#   ('synapse_Rh6-PR-10-R_Pdf-LaN-4-R',
#    'Pdf-LaN-4-R',
#    {'id': '791', 'weight': nan}),
#   ('synapse_Pdf-LaN-3-R_Pdf-LaN-1-R',
#    'Pdf-LaN-1-R',
#    {'id': '792', 'weight': nan}),
#   ('synapse_Phasic-VPN-R_cha-lOLP-R',
#    'cha-lOLP-R',
#    {'id': '793', 'weight': nan}),
#   ('synapse_glu-lOLP-L_Pdf-LaN-2-L',
#    'Pdf-LaN-2-L',
#    {'id': '794', 'weight': nan}),
#   ('synapse_extra-glu-lOLP-R_cha-lOLP-R',
#    'cha-lOLP-R',
#    {'id': '795', 'weight': nan}),
#   ('synapse_Rh6-PR-8-L_glu-lOLP-L',
#    'glu-lOLP-L',
#    {'id': '796', 'weight': nan}),
#   ('Rh5-PR-6-R',
#    'synapse_Rh5-PR-6-R_nc-LaN-1-R',
#    {'id': '797', 'weight': 6.0}),
#   ('Rh5-PR-6-R',
#    'synapse_Rh5-PR-6-R_Pdf-LaN-3-R',
#    {'id': '798', 'weight': 1.0}),
#   ('Rh5-PR-6-R', 'synapse_Rh5-PR-6-R_5th-LaN-R', {'id': '799', 'weight': 8.0}),
#   ('Rh5-PR-6-R',
#    'synapse_Rh5-PR-6-R_Pdf-LaN-1-R',
#    {'id': '800', 'weight': 2.0}),
#   ('Rh5-PR-6-R', 'synapse_Rh5-PR-6-R_pOLP-R', {'id': '801', 'weight': 3.0}),
#   ('Rh5-PR-6-R',
#    'synapse_Rh5-PR-6-R_Pdf-LaN-2-R',
#    {'id': '802', 'weight': 4.0}),
#   ('Rh5-PR-6-R',
#    'synapse_Rh5-PR-6-R_Pdf-LaN-4-R',
#    {'id': '803', 'weight': 1.0}),
#   ('Rh5-PR-6-R',
#    'synapse_Rh5-PR-6-R_extra-glu-lOLP-R',
#    {'id': '804', 'weight': 6.0}),
#   ('Rh5-PR-6-R',
#    'synapse_Rh5-PR-6-R_nc-LaN-2-R',
#    {'id': '805', 'weight': 14.0}),
#   ('Rh5-PR-6-R',
#    'synapse_Rh5-PR-6-R_cha-lOLP-R',
#    {'id': '806', 'weight': 2.0}),
#   ('Rh5-PR-6-R', 'synapse_Rh5-PR-6-R_PVL09-R', {'id': '807', 'weight': 11.0}),
#   ('PVL09-L', 'synapse_PVL09-L_PVL09-L', {'id': '808', 'weight': 1.0}),
#   ('PVL09-L', 'synapse_PVL09-L_pOLP-L', {'id': '809', 'weight': 15.0}),
#   ('synapse_Rh6-PR-8-L_Pdf-LaN-2-L',
#    'Pdf-LaN-2-L',
#    {'id': '810', 'weight': nan}),
#   ('synapse_Rh6-PR-2-R_Pdf-LaN-4-R',
#    'Pdf-LaN-4-R',
#    {'id': '811', 'weight': nan}),
#   ('synapse_sVUM2mx-L_5th-LaN-L', '5th-LaN-L', {'id': '812', 'weight': nan}),
#   ('synapse_Rh5-PR-1-L_nc-LaN-2-L',
#    'nc-LaN-2-L',
#    {'id': '813', 'weight': nan}),
#   ('synapse_Rh5-PR-3-L_PVL09-L', 'PVL09-L', {'id': '814', 'weight': nan}),
#   ('synapse_Rh6-PR-5-R_Pdf-LaN-1-R',
#    'Pdf-LaN-1-R',
#    {'id': '815', 'weight': nan}),
#   ('PVL09-R', 'synapse_PVL09-R_pOLP-R', {'id': '816', 'weight': 10.0}),
#   ('PVL09-R', 'synapse_PVL09-R_nc-LaN-1-R', {'id': '817', 'weight': 1.0}),
#   ('Rh6-PR-3-L', 'synapse_Rh6-PR-3-L_PVL09-L', {'id': '818', 'weight': 1.0}),
#   ('Rh6-PR-3-L',
#    'synapse_Rh6-PR-3-L_glu-lOLP-L',
#    {'id': '819', 'weight': 23.0}),
#   ('Rh6-PR-3-L',
#    'synapse_Rh6-PR-3-L_Pdf-LaN-4-L',
#    {'id': '820', 'weight': 1.0}),
#   ('Rh6-PR-3-L',
#    'synapse_Rh6-PR-3-L_Pdf-LaN-3-L',
#    {'id': '821', 'weight': 3.0}),
#   ('Rh6-PR-3-L',
#    'synapse_Rh6-PR-3-L_Pdf-LaN-1-L',
#    {'id': '822', 'weight': 1.0}),
#   ('Rh6-PR-3-L',
#    'synapse_Rh6-PR-3-L_cha-lOLP-L',
#    {'id': '823', 'weight': 26.0}),
#   ('synapse_nc-LaN-1-L_5th-LaN-L', '5th-LaN-L', {'id': '824', 'weight': nan}),
#   ('synapse_Rh6-PR-2-R_Pdf-LaN-3-R',
#    'Pdf-LaN-3-R',
#    {'id': '825', 'weight': nan}),
#   ('synapse_Rh5-PR-1-L_5th-LaN-L', '5th-LaN-L', {'id': '826', 'weight': nan}),
#   ('synapse_Rh6-PR-1-L_Pdf-LaN-2-L',
#    'Pdf-LaN-2-L',
#    {'id': '827', 'weight': nan}),
#   ('synapse_extra-glu-lOLP-R_Pdf-LaN-1-R',
#    'Pdf-LaN-1-R',
#    {'id': '828', 'weight': nan}),
#   ('synapse_Phasic-VPN-R_Pdf-LaN-3-R',
#    'Pdf-LaN-3-R',
#    {'id': '829', 'weight': nan}),
#   ('synapse_Rh6-PR-1-L_Pdf-LaN-1-L',
#    'Pdf-LaN-1-L',
#    {'id': '830', 'weight': nan}),
#   ('synapse_glu-lOLP-L_Phasic-VPN-L',
#    'Phasic-VPN-L',
#    {'id': '831', 'weight': nan}),
#   ('synapse_Rh6-PR-5-R_Pdf-LaN-2-R',
#    'Pdf-LaN-2-R',
#    {'id': '832', 'weight': nan}),
#   ('synapse_Phasic-VPN-R_Pdf-LaN-4-R',
#    'Pdf-LaN-4-R',
#    {'id': '833', 'weight': nan}),
#   ('synapse_5th-LaN-L_Pdf-LaN-2-L',
#    'Pdf-LaN-2-L',
#    {'id': '834', 'weight': nan}),
#   ('synapse_extra-glu-lOLP-R_Pdf-LaN-4-R',
#    'Pdf-LaN-4-R',
#    {'id': '835', 'weight': nan}),
#   ('synapse_extra-glu-lOLP-R_Pdf-LaN-2-R',
#    'Pdf-LaN-2-R',
#    {'id': '836', 'weight': nan}),
#   ('synapse_5th-LaN-L_Pdf-LaN-1-L',
#    'Pdf-LaN-1-L',
#    {'id': '837', 'weight': nan}),
#   ('synapse_Rh5-PR-2-L_Pdf-LaN-2-L',
#    'Pdf-LaN-2-L',
#    {'id': '838', 'weight': nan}),
#   ('synapse_Rh5-PR-1-R_PVL09-R', 'PVL09-R', {'id': '839', 'weight': nan}),
#   ('synapse_Rh6-PR-3-R_glu-lOLP-R',
#    'glu-lOLP-R',
#    {'id': '840', 'weight': nan}),
#   ('synapse_nc-LaN-1-R_glu-lOLP-R',
#    'glu-lOLP-R',
#    {'id': '841', 'weight': nan}),
#   ('synapse_nc-LaN-2-L_PVL09-L', 'PVL09-L', {'id': '842', 'weight': nan}),
#   ('synapse_glu-lOLP-L_5th-LaN-L', '5th-LaN-L', {'id': '843', 'weight': nan})],
#  'directed': True}

# %%
set(nx.get_node_attributes(G,'class').values())
# Out:
# {'MorrisLecar', 'PowerGPotGPot'}

# %%
ng = NeuGraph.from_gexf('lon.gexf')

# %%
ng
# Out:
# NeuGraph(data={'nodes': [('nc-LaN-1-R', {'phi': 0.001, 'initn': 0.3525, 'g_Ca': 4.0, 'offset': 0.0, 'V_L': -40…
